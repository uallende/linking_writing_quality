# %% [markdown]
# # FE + Null Importance + LGB (CV:0.616->0.615, LB:0.582->0.584)
# Six years ago, Kaggle GM Olivier proposed the **[Null Importance](https://www.kaggle.com/code/ogrellier/feature-selection-with-null-importances/notebook)** feature selection method. It could identifies and removes "opportunistic" features. For example, if we include userID as a feature in the model to predict the consumer category to which different userIDs belong, an overfitted model might learn a direct mapping from userID to the consumer group (essentially memorizing which consumer category corresponds to which userID). If we shuffle the labels and retrain the model to make predictions based on the shuffled labels, we would find that the model would once again map the userID directly to the shuffled labels. Ultimately, regardless of whether the labels are real or fake, the userID becomes an "opportunistic" feature that makes itself the most important. How do we identify such features? Olivier's idea is simple: **truly robust, stable, and important features should be highly important under the real labels, but their importance should diminish once the labels are shuffled.** Conversely, if a feature performs moderately under the raw labels but its importance increases when the labels are shuffled, it is clearly unreliable and should be removed as an "opportunistic" feature.
#
# Based on [Silver Bullet | Single Model | 165 Features](https://www.kaggle.com/code/awqatak/silver-bullet-single-model-165-features), I made the following modifications:
# - Add early stopping.
# - Add Null Importance.
#
# **The offline CV decreases from 0.616 to 0.615, while the public score increases from 0.582 to 0.584. **
#
# I conducted some experiments and found that inconsistencies between offline and online performance are often present. Therefore, I decided to share the null importances for public, even though they may not perform optimally online. However, I believe it provides valuable insights. I also hope that find a teammate. I am less concerned about the results on the public leaderboard. Instead, I may focus on improving the performance of both offline and online metrics by relying on feature engineering and enhancing model generalization.

# %%
import polars as pl
import pandas as pd
import numpy as np
import time
import re, os
import random
import optuna
from tqdm import tqdm
import lightgbm
from lightgbm import LGBMRegressor
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
from scipy.stats import skew, kurtosis
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import warnings
warnings.filterwarnings("ignore")

# %%
os.mkdir('feature_selection/')
os.mkdir('results')

# %% [markdown]
# ## Feature Engineering

# %%
num_cols = ['down_time', 'up_time', 'action_time', 'cursor_position', 'word_count']
activities = ['Input', 'Remove/Cut', 'Nonproduction', 'Replace', 'Paste']
events = ['q', 'Space', 'Backspace', 'Shift', 'ArrowRight', 'Leftclick', 'ArrowLeft', '.', ',', 'ArrowDown', 'ArrowUp', 'Enter', 'CapsLock', "'", 'Delete', 'Unidentified']
text_changes = ['q', ' ', '.', ',', '\n', "'", '"', '-', '?', ';', '=', '/', '\\', ':']

def count_by_values(df, colname, values):
    fts = df.select(pl.col('id').unique(maintain_order=True))
    for i, value in enumerate(values):
        tmp_df = df.group_by('id').agg(pl.col(colname).is_in([value]).sum().alias(f'{colname}_{i}_cnt'))
        fts  = fts.join(tmp_df, on='id', how='left') 
    return fts

def dev_feats(df):
    
    print("< Count by values features >")
    feats = count_by_values(df, 'activity', activities)
    feats = feats.join(count_by_values(df, 'text_change', text_changes), on='id', how='left') 
    feats = feats.join(count_by_values(df, 'down_event', events), on='id', how='left') 
    feats = feats.join(count_by_values(df, 'up_event', events), on='id', how='left') 

    print("< Input words stats features >")
    temp = df.filter((~pl.col('text_change').str.contains('=>')) & (pl.col('text_change') != 'NoChange'))
    temp = temp.group_by('id').agg(pl.col('text_change').str.concat('').str.extract_all(r'q+'))
    temp = temp.with_columns(input_word_count = pl.col('text_change').list.lengths(), 
                             input_word_length_mean = pl.col('text_change').apply(lambda x: np.mean([len(i) for i in x] if len(x) > 0 else 0)),
                             input_word_length_max = pl.col('text_change').apply(lambda x: np.max([len(i) for i in x] if len(x) > 0 else 0)),
                             input_word_length_std = pl.col('text_change').apply(lambda x: np.std([len(i) for i in x] if len(x) > 0 else 0)),
                             input_word_length_median = pl.col('text_change').apply(lambda x: np.median([len(i) for i in x] if len(x) > 0 else 0)),
                             input_word_length_skew = pl.col('text_change').apply(lambda x: skew([len(i) for i in x] if len(x) > 0 else 0)))
    temp = temp.drop('text_change')
    feats = feats.join(temp, on='id', how='left') 
   
    print("< Numerical columns features >")
    temp = df.group_by("id").agg(pl.sum('action_time').suffix('_sum'), pl.mean(num_cols).suffix('_mean'), pl.std(num_cols).suffix('_std'),
                                 pl.median(num_cols).suffix('_median'), pl.min(num_cols).suffix('_min'), pl.max(num_cols).suffix('_max'),
                                 pl.quantile(num_cols, 0.5).suffix('_quantile'))
    feats = feats.join(temp, on='id', how='left') 

    print("< Categorical columns features >")
    temp  = df.group_by("id").agg(pl.n_unique(['activity', 'down_event', 'up_event', 'text_change']))
    feats = feats.join(temp, on='id', how='left') 

    print("< Idle time features >")
    # time_diff = abs(down_time - up_time_lagged) 
    temp = df.with_columns(pl.col('up_time').shift().over('id').alias('up_time_lagged'))
    temp = temp.with_columns((abs(pl.col('down_time') - pl.col('up_time_lagged')) / 1000).fill_null(0).alias('time_diff'))
    temp = temp.filter(pl.col('activity').is_in(['Input', 'Remove/Cut']))
    temp = temp.group_by("id").agg(inter_key_largest_lantency = pl.max('time_diff'),
                                   inter_key_median_lantency = pl.median('time_diff'),
                                   mean_pause_time = pl.mean('time_diff'),
                                   std_pause_time = pl.std('time_diff'),
                                   total_pause_time = pl.sum('time_diff'),
                                   pauses_half_sec = pl.col('time_diff').filter((pl.col('time_diff') > 0.5) & (pl.col('time_diff') < 1)).count(),
                                   pauses_1_sec = pl.col('time_diff').filter((pl.col('time_diff') > 1) & (pl.col('time_diff') < 1.5)).count(),
                                   pauses_1_half_sec = pl.col('time_diff').filter((pl.col('time_diff') > 1.5) & (pl.col('time_diff') < 2)).count(),
                                   pauses_2_sec = pl.col('time_diff').filter((pl.col('time_diff') > 2) & (pl.col('time_diff') < 3)).count(),
                                   pauses_3_sec = pl.col('time_diff').filter(pl.col('time_diff') > 3).count(),)
    feats = feats.join(temp, on='id', how='left') 
    
    print("< P-bursts features >")
    # P-bursts that refer to the written segments terminated by pauses
    temp = df.with_columns(pl.col('up_time').shift().over('id').alias('up_time_lagged'))
    temp = temp.with_columns((abs(pl.col('down_time') - pl.col('up_time_lagged')) / 1000).fill_null(0).alias('time_diff'))
    temp = temp.filter(pl.col('activity').is_in(['Input', 'Remove/Cut']))
    temp = temp.with_columns(pl.col('time_diff')<2)
    temp = temp.with_columns(pl.when(pl.col("time_diff") & pl.col("time_diff").is_last()).then(pl.count()).over(pl.col("time_diff").rle_id()).alias('P-bursts'))
    temp = temp.drop_nulls()
    temp = temp.group_by("id").agg(pl.mean('P-bursts').suffix('_mean'), pl.std('P-bursts').suffix('_std'), pl.count('P-bursts').suffix('_count'),
                                   pl.median('P-bursts').suffix('_median'), pl.max('P-bursts').suffix('_max'),
                                   pl.first('P-bursts').suffix('_first'), pl.last('P-bursts').suffix('_last'))
    feats = feats.join(temp, on='id', how='left') 

    print("< R-bursts features >")
    # R-bursts that describe the segments terminated by an evaluation, revision or other grammatical discontinuity
    temp = df.filter(pl.col('activity').is_in(['Input', 'Remove/Cut']))
    temp = temp.with_columns(pl.col('activity').is_in(['Remove/Cut']))
    temp = temp.with_columns(pl.when(pl.col("activity") & pl.col("activity").is_last()).then(pl.count()).over(pl.col("activity").rle_id()).alias('R-bursts'))
    temp = temp.drop_nulls()
    temp = temp.group_by("id").agg(pl.mean('R-bursts').suffix('_mean'), pl.std('R-bursts').suffix('_std'), 
                                   pl.median('R-bursts').suffix('_median'), pl.max('R-bursts').suffix('_max'),
                                   pl.first('R-bursts').suffix('_first'), pl.last('R-bursts').suffix('_last'))
    feats = feats.join(temp, on='id', how='left')
    return feats

# %% [markdown]
# ## Reconstruct Essay

# %%
def reconstruct_essay(currTextInput):
    essayText = ""
    for Input in currTextInput.values:
        # Input[0] = activity
        # Input[1] = cursor_position
        # Input[2] = text_change
        # Input[3] = id
        if Input[0] == 'Replace':
            replaceTxt = Input[2].split(' => ')
            essayText = essayText[:Input[1] - len(replaceTxt[1])] + replaceTxt[1] + essayText[Input[1] - len(replaceTxt[1]) + len(replaceTxt[0]):]
            continue
        if Input[0] == 'Paste':
            essayText = essayText[:Input[1] - len(Input[2])] + Input[2] + essayText[Input[1] - len(Input[2]):]
            continue
        if Input[0] == 'Remove/Cut':
            essayText = essayText[:Input[1]] + essayText[Input[1] + len(Input[2]):]
            continue
        # If activity = Move...
        if "M" in Input[0]:
            # Gets rid of the "Move from to" text
            croppedTxt = Input[0][10:]
            # Splits cropped text by ' To '
            splitTxt = croppedTxt.split(' To ')
            # Splits split text again by ', ' for each item
            valueArr = [item.split(', ') for item in splitTxt]
            # Move from [2, 4] To [5, 7] = (2, 4, 5, 7)
            moveData = (int(valueArr[0][0][1:]), int(valueArr[0][1][:-1]), int(valueArr[1][0][1:]), int(valueArr[1][1][:-1]))
            # Skip if someone manages to activiate this by moving to same place
            if moveData[0] != moveData[2]:
                # Check if they move text forward in essay (they are different)
                if moveData[0] < moveData[2]:
                    essayText = essayText[:moveData[0]] + essayText[moveData[1]:moveData[3]] + essayText[moveData[0]:moveData[1]] + essayText[moveData[3]:]
                else:
                    essayText = essayText[:moveData[2]] + essayText[moveData[0]:moveData[1]] + essayText[moveData[2]:moveData[0]] + essayText[moveData[1]:]
            continue
        # If activity = input
        essayText = essayText[:Input[1] - len(Input[2])] + Input[2] + essayText[Input[1] - len(Input[2]):]
    return essayText

def get_essay_df(df):
    df       = df[df.activity != 'Nonproduction']
    temp     = df.groupby('id').apply(lambda x: reconstruct_essay(x[['activity', 'cursor_position', 'text_change']]))
    essay_df = pd.DataFrame({'id': df['id'].unique().tolist()})
    essay_df = essay_df.merge(temp.rename('essay'), on='id')
    return essay_df

# %%
def q1(x):
    return x.quantile(0.25)
def q3(x):
    return x.quantile(0.75)

AGGREGATIONS = ['count', 'mean', 'min', 'max', 'first', 'last', q1, 'median', q3, 'sum']

def word_feats(df):
    df['word'] = df['essay'].apply(lambda x: re.split(' |\\n|\\.|\\?|\\!',x))
    # a list of words to each word per row
    df = df.explode('word')
    df['word_len'] = df['word'].apply(lambda x: len(x))
    df = df[df['word_len'] != 0]

    word_agg_df = df[['id','word_len']].groupby(['id']).agg(AGGREGATIONS)
    word_agg_df.columns = ['_'.join(x) for x in word_agg_df.columns]
    word_agg_df['id'] = word_agg_df.index
    word_agg_df = word_agg_df.reset_index(drop=True) 
    return word_agg_df

def sent_feats(df):
    df['sent'] = df['essay'].apply(lambda x: re.split('\\.|\\?|\\!',x))
    df = df.explode('sent')
    df['sent'] = df['sent'].apply(lambda x: x.replace('\n','').strip())
    # Number of characters in sentences
    df['sent_len'] = df['sent'].apply(lambda x: len(x))
    # Number of words in sentences
    df['sent_word_count'] = df['sent'].apply(lambda x: len(x.split(' ')))
    df = df[df.sent_len!=0].reset_index(drop=True)

    sent_agg_df = pd.concat([df[['id','sent_len']].groupby(['id']).agg(AGGREGATIONS), 
                             df[['id','sent_word_count']].groupby(['id']).agg(AGGREGATIONS)], axis=1)
    sent_agg_df.columns = ['_'.join(x) for x in sent_agg_df.columns]
    sent_agg_df['id'] = sent_agg_df.index
    sent_agg_df = sent_agg_df.reset_index(drop=True)
    sent_agg_df.drop(columns=["sent_word_count_count"], inplace=True)
    sent_agg_df = sent_agg_df.rename(columns={"sent_len_count":"sent_count"})
    return sent_agg_df

def parag_feats(df):
    df['paragraph'] = df['essay'].apply(lambda x: x.split('\n'))
    df = df.explode('paragraph')
    # Number of characters in paragraphs
    df['paragraph_len'] = df['paragraph'].apply(lambda x: len(x)) 
    # Number of words in paragraphs
    df['paragraph_word_count'] = df['paragraph'].apply(lambda x: len(x.split(' ')))
    df = df[df.paragraph_len!=0].reset_index(drop=True)
    
    paragraph_agg_df = pd.concat([df[['id','paragraph_len']].groupby(['id']).agg(AGGREGATIONS), 
                                  df[['id','paragraph_word_count']].groupby(['id']).agg(AGGREGATIONS)], axis=1) 
    paragraph_agg_df.columns = ['_'.join(x) for x in paragraph_agg_df.columns]
    paragraph_agg_df['id'] = paragraph_agg_df.index
    paragraph_agg_df = paragraph_agg_df.reset_index(drop=True)
    paragraph_agg_df.drop(columns=["paragraph_word_count_count"], inplace=True)
    paragraph_agg_df = paragraph_agg_df.rename(columns={"paragraph_len_count":"paragraph_count"})
    return paragraph_agg_df
    
def product_to_keys(logs, essays):
    essays['product_len'] = essays.essay.str.len()
    tmp_df = logs[logs.activity.isin(['Input', 'Remove/Cut'])].groupby(['id']).agg({'activity': 'count'}).reset_index().rename(columns={'activity': 'keys_pressed'})
    essays = essays.merge(tmp_df, on='id', how='left')
    essays['product_to_keys'] = essays['product_len'] / essays['keys_pressed']
    return essays[['id', 'product_to_keys']]

def get_keys_pressed_per_second(logs):
    temp_df = logs[logs['activity'].isin(['Input', 'Remove/Cut'])].groupby(['id']).agg(keys_pressed=('event_id', 'count')).reset_index()
    temp_df_2 = logs.groupby(['id']).agg(min_down_time=('down_time', 'min'), max_up_time=('up_time', 'max')).reset_index()
    temp_df = temp_df.merge(temp_df_2, on='id', how='left')
    temp_df['keys_per_second'] = temp_df['keys_pressed'] / ((temp_df['max_up_time'] - temp_df['min_down_time']) / 1000)
    return temp_df[['id', 'keys_per_second']]

# %% [markdown]
# ## Feature Selection: Null Importances

# %%
def get_feature_importances(data_x, data_y, valid_x, valid_y, model_params, shuffle, seed=None):
    if seed == None:
        model_params['random_state'] = None

    gain_model = LGBMRegressor(importance_type='gain', **model_params)
    split_model = LGBMRegressor(importance_type='split', **model_params)

    if shuffle:
        random.shuffle(data_y)
        random.shuffle(valid_y)
        
    gain_model.fit(data_x, data_y, eval_set=[(valid_x, valid_y)], verbose=False)
    split_model.fit(data_x, data_y, eval_set=[(valid_x, valid_y)], verbose=False)

    imp_df = pd.DataFrame()
    imp_df["feature"] = list(data_x)
    imp_df["importance_gain"] = gain_model.feature_importances_
    imp_df["importance_split"] = split_model.feature_importances_    
    return imp_df


def get_batch_imp_df(data_x, data_y, valid_x, valid_y, model_params, nb_runs=10, null_flag=True):
    batch_imp_df = pd.DataFrame()
    print(f'Run {nb_runs} rounds of model training:')
    for i in tqdm(range(nb_runs)):
        if null_flag:
            imp_df = get_feature_importances(data_x, data_y, valid_x, valid_y, model_params, shuffle=True, seed=None)
        else:
            imp_df = get_feature_importances(data_x, data_y, valid_x, valid_y, model_params, shuffle=False, seed=None)
        imp_df['run'] = i + 1 
        batch_imp_df = pd.concat([batch_imp_df, imp_df], axis=0)
    return batch_imp_df


def display_distributions(actual_imp_df_, null_imp_df_, feature_):
    plt.figure(figsize=(13, 6))
    gs = gridspec.GridSpec(1, 2)
    # Plot Split importances
    ax = plt.subplot(gs[0, 0])
    a = ax.hist(null_imp_df_.loc[null_imp_df_['feature'] == feature_, 'importance_split'].values, label='Null importances')
    ax.vlines(x=actual_imp_df_.loc[actual_imp_df_['feature'] == feature_, 'importance_split'].mean(), 
               ymin=0, ymax=np.max(a[0]), color='r',linewidth=10, label='Real Target')
    ax.legend()
    ax.set_title('Split Importance of %s' % feature_.upper(), fontweight='bold')
    plt.xlabel('Null Importance (split) Distribution for %s ' % feature_.upper())
    # Plot Gain importances
    ax = plt.subplot(gs[0, 1])
    a = ax.hist(null_imp_df_.loc[null_imp_df_['feature'] == feature_, 'importance_gain'].values, label='Null importances')
    ax.vlines(x=actual_imp_df_.loc[actual_imp_df_['feature'] == feature_, 'importance_gain'].mean(), 
               ymin=0, ymax=np.max(a[0]), color='r',linewidth=10, label='Real Target')
    ax.legend()
    ax.set_title('Gain Importance of %s' % feature_.upper(), fontweight='bold')
    plt.xlabel('Null Importance (gain) Distribution for %s ' % feature_.upper())

    
def normalize_feat_imp(imp_df):
    avg_gain_imp_df = imp_df.groupby(by=['feature'])['importance_gain'].mean().reset_index()
    avg_split_imp_df = imp_df.groupby(by=['feature'])['importance_split'].mean().reset_index()
    # rank-normalize score
    avg_gain_imp_df['importance_gain'] = avg_gain_imp_df['importance_gain'].rank(ascending=False, pct=True)
    avg_split_imp_df['importance_split'] = avg_split_imp_df['importance_split'].rank(ascending=False, pct=True)
    avg_imp_df = pd.merge(avg_gain_imp_df, avg_split_imp_df, on='feature')
    # # normalize score
    # avg_imp_df['importance_gain'] = (avg_imp_df['importance_gain'] - avg_imp_df['importance_gain'].min())  / (avg_imp_df['importance_gain'].max() - avg_imp_df['importance_gain'].min())
    # avg_imp_df['importance_split'] = (avg_imp_df['importance_split'] - avg_imp_df['importance_split'].min())  / (avg_imp_df['importance_split'].max() - avg_imp_df['importance_split'].min())
    return avg_imp_df


def nul_imp_feat_select(model_params,
                        train_x, train_y, valid_x, valid_y,
                        actual_avg_imp_df, null_avg_imp_df,
                        search_thres=[ 0.5, 0.6, 0.7, 0.8, 0.9, 0.95, 1],
                        search_criterion=['gain', 'split', 'both']):
    feat_select_dfs = []
    for search_cri in search_criterion:
        print(f'Feature Selection by Null Importances: {search_cri}:')
        for threshold in tqdm(search_thres):
            if 'split' == search_cri:
                actual_feats = actual_avg_imp_df[actual_avg_imp_df['importance_split']>threshold]['feature'].values.tolist()
                null_feats = null_avg_imp_df[null_avg_imp_df['importance_split']>threshold]['feature'].values.tolist()
                unstable_feats = set(actual_feats + null_feats)
                feats = [_f for _f in actual_avg_imp_df['feature'].unique() if _f not in unstable_feats]
            elif 'gain' == search_cri:
                actual_feats = actual_avg_imp_df[actual_avg_imp_df['importance_gain']>threshold]['feature'].values.tolist()
                null_feats = null_avg_imp_df[null_avg_imp_df['importance_gain']>threshold]['feature'].values.tolist()
                unstable_feats = set(actual_feats + null_feats)
                feats = [_f for _f in actual_avg_imp_df['feature'].unique() if _f not in unstable_feats]
            elif 'both' == search_cri:
                actual_feats = actual_avg_imp_df[actual_avg_imp_df['importance_split']>threshold]['feature'].values.tolist()
                null_feats = null_avg_imp_df[null_avg_imp_df['importance_split']>threshold]['feature'].values.tolist()
                unstable_feats1 = set(actual_feats + null_feats)

                actual_feats = actual_avg_imp_df[actual_avg_imp_df['importance_gain']>threshold]['feature'].values.tolist()
                null_feats = null_avg_imp_df[null_avg_imp_df['importance_gain']>threshold]['feature'].values.tolist()
                unstable_feats2 = set(actual_feats + null_feats)
                
                unstable_feats = set(list(unstable_feats1) + list(unstable_feats2))
                feats = [_f for _f in actual_avg_imp_df['feature'].unique() if _f not in unstable_feats]

            model = LGBMRegressor(**model_params)
            model.fit(train_x[feats], train_y, eval_set=[(valid_x[feats], valid_y)], verbose= False)
            valid_pred_y = model.predict(valid_x[feats], num_iteration=model.best_iteration_)  
            valid_eval_rmse = mean_squared_error(valid_y, valid_pred_y, squared=False) 
            feat_select_dfs.append([search_cri, threshold, feats, len(feats), valid_eval_rmse])
    feat_select_dfs = pd.DataFrame(feat_select_dfs)   
    feat_select_dfs.columns = ['imp_type', 'threshold', 'features', 'feature_number', 'valid_eval_rmse']    
    return feat_select_dfs

# %% [markdown]
# ## Data Loading

# %%
data_path     = 'kaggle/input/linking-writing-processes-to-writing-quality/'
train_logs    = pl.scan_csv(data_path + 'train_logs.csv')
train_feats   = dev_feats(train_logs) # 特征工程
train_feats   = train_feats.collect().to_pandas()

print('< Essay Reconstruction >')
train_logs             = train_logs.collect().to_pandas()
train_essays           = get_essay_df(train_logs)
train_feats            = train_feats.merge(word_feats(train_essays), on='id', how='left')
train_feats            = train_feats.merge(sent_feats(train_essays), on='id', how='left')
train_feats            = train_feats.merge(parag_feats(train_essays), on='id', how='left')
train_feats            = train_feats.merge(get_keys_pressed_per_second(train_logs), on='id', how='left')
train_feats            = train_feats.merge(product_to_keys(train_logs, train_essays), on='id', how='left')


print('< Mapping >')
train_scores   = pd.read_csv(data_path + 'train_scores.csv')
data           = train_feats.merge(train_scores, on='id', how='left')
x              = data.drop(['id', 'score'], axis=1)
y              = data['score'].values
print(f'Number of features: {len(x.columns)}')
# Out:
# < Count by values features >
# < Input words stats features >
# < Numerical columns features >
# < Categorical columns features >
# < Idle time features >
# < P-bursts features >
# < R-bursts features >
# < Essay Reconstruction >
# < Mapping >
# Number of features: 165

# %% [markdown]
# ## Model Training

# %%
def train_valid_split(data_x, data_y, train_idx, valid_idx):
    x_train = data_x.iloc[train_idx]
    y_train = data_y[train_idx]
    x_valid = data_x.iloc[valid_idx]
    y_valid = data_y[valid_idx]
    return x_train, y_train, x_valid, y_valid

def evaluate(data_x, data_y, model, random_state=42, n_splits=5):
    skf    = StratifiedKFold(n_splits=n_splits, random_state=random_state, shuffle=True)
    test_y = np.zeros(len(data_x))
    feature_list = list(data_x)
    avg_feature_imp = pd.DataFrame({'feature':feature_list, 'importance':np.zeros(len(feature_list))})

    for i, (train_index, valid_index) in enumerate(skf.split(data_x, data_y.astype(str))):
        print(f'Fold:{i}:')
        train_x, train_y, valid_x, valid_y = train_valid_split(data_x, data_y, train_index, valid_index)

        model.fit(train_x, train_y, 
                  eval_set=[(valid_x, valid_y)],
                 )
        test_y[valid_index] = model.predict(valid_x, num_iteration=model.best_iteration_)
        model.booster_.save_model(f'results/model_fold{i}.txt', num_iteration=model.best_iteration_)

        importances = model.feature_importances_
        
        feature_imp = pd.DataFrame({'feature':feature_list, 'importance':importances})
        feature_imp['importance'] = (feature_imp['importance'] - feature_imp['importance'].min())  / (feature_imp['importance'].max() - feature_imp['importance'].min())
        avg_feature_imp['importance'] += feature_imp['importance']
        feature_imp = feature_imp.sort_values(by='importance', ascending=False)
        feature_imp.to_csv(f'results/model_feat_imp_fold{i}.csv', index=False)
        print('-'*20)

    eval_rmse = mean_squared_error(data_y, test_y, squared=False)
    avg_feature_imp['importance'] /= n_splits
    avg_feature_imp = avg_feature_imp.sort_values(by='importance', ascending=False)
    avg_feature_imp.to_csv('results/model_feat_imp_avg.csv', index=False)
    return test_y, eval_rmse, avg_feature_imp

def inference(n_splits=5, test_x=None):
    test_y = np.zeros((len(test_x), n_splits))
    for i in range(n_splits):
        use_feats = np.load(f'feature_selection/optimal_feat_select_res_fold{i}.npy', allow_pickle=True)
        model = lightgbm.Booster(model_file=f'results/model_fold{i}.txt')
        test_y[:, i] = model.predict(test_x[use_feats[2]])
    return np.mean(test_y, axis=1)

# %%
param = {
        'n_estimators': 1024,
         'learning_rate': 0.005,
         'metric': 'rmse',
         'random_state': 42,
         'force_col_wise': True,
         'verbosity': -1,
         'early_stopping_round': 100
        }


data_x = x.copy()
data_y = y.copy()
model_params = param
random_state = 42
n_splits = 5
nb_runs = 50
train_feat_select = True

skf    = StratifiedKFold(n_splits=n_splits, random_state=random_state, shuffle=True)
test_y = np.zeros(len(data_x))

for i, (train_index, valid_index) in enumerate(skf.split(data_x, data_y.astype(str))):
    print(f'Fold:{i}:')
    train_x, train_y, valid_x, valid_y = train_valid_split(data_x, data_y, train_index, valid_index)

    if train_feat_select:
        print('Feature Selection (get null_imp_df):')
        null_imp_df = get_batch_imp_df(data_x.copy(), data_y.copy(), valid_x.copy(), valid_y.copy(), model_params, nb_runs=nb_runs, null_flag=True)
        print('Feature Selection (actual_imp_df):')
        actual_imp_df = get_batch_imp_df(data_x.copy(), data_y.copy(), valid_x.copy(), valid_y.copy(), model_params, nb_runs=nb_runs, null_flag=False)

        actual_avg_imp_df = normalize_feat_imp(actual_imp_df)
        null_avg_imp_df = normalize_feat_imp(null_imp_df)
        feat_select_dfs = nul_imp_feat_select(model_params,
                            train_x, train_y, valid_x, valid_y,
                            actual_avg_imp_df, null_avg_imp_df,
                            search_thres=[0.5, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 1],
                            search_criterion=['gain', 'split', 'both'])
        
        if not os.path.exists('feature_selection/'):
            os.mkdir('feature_selection/')
        feat_select_dfs.to_csv(f'feature_selection/feature_selection_res_fold{i}.csv', index=False)
        valid_min_eval_rmse = feat_select_dfs['valid_eval_rmse'].min()
        optimal_feat_select_res = feat_select_dfs[feat_select_dfs['valid_eval_rmse'] == valid_min_eval_rmse].values[0]
        np.save(f'feature_selection/optimal_feat_select_res_fold{i}.npy', optimal_feat_select_res)

    use_feats = np.load(f'feature_selection/optimal_feat_select_res_fold{i}.npy', allow_pickle=True)
    print(f'After feature selection: {len(list(train_x))} -> {len(use_feats[2])}.')
    train_x = train_x[use_feats[2]]
    valid_x = valid_x[use_feats[2]]

    model = LGBMRegressor(**model_params)
    model.fit(train_x, train_y, 
            #   eval_set=[(train_x, train_y), (valid_x, valid_y)],
                eval_set=[(valid_x, valid_y)],
                )
    test_y[valid_index] = model.predict(valid_x, num_iteration=model.best_iteration_)

    model.booster_.save_model(f'results/model_fold{i}.txt', num_iteration=model.best_iteration_)


    importances = model.feature_importances_
    feature_list = list(train_x)
    feature_imp = pd.DataFrame({'feature':feature_list, 'importance':importances})
    feature_imp['importance'] = (feature_imp['importance'] - feature_imp['importance'].min())  / (feature_imp['importance'].max() - feature_imp['importance'].min())
    feature_imp = feature_imp.sort_values(by='importance', ascending=False)
    feature_imp.to_csv(f'results/model_feat_imp_fold{i}.csv', index=False)
    print('-'*20)
    del model

eval_rmse = mean_squared_error(data_y, test_y, squared=False)
print('Eval RMSE:', eval_rmse)
# Out:
# Fold:0:
# Feature Selection (get null_imp_df):
# Run 50 rounds of model training:
# 100%|██████████| 50/50 [03:21<00:00,  4.04s/it]
# Feature Selection (actual_imp_df):
# Run 50 rounds of model training:
# 100%|██████████| 50/50 [28:24<00:00, 34.09s/it]
# Feature Selection by Null Importances: gain:
# 100%|██████████| 9/9 [01:53<00:00, 12.60s/it]
# Feature Selection by Null Importances: split:
# 100%|██████████| 9/9 [01:56<00:00, 12.97s/it]
# Feature Selection by Null Importances: both:
# 100%|██████████| 9/9 [01:56<00:00, 12.94s/it]
# After feature selection: 165 -> 105.
# [1]	valid_0's rmse: 1.01967
# [2]	valid_0's rmse: 1.01669
# [3]	valid_0's rmse: 1.0137
# [4]	valid_0's rmse: 1.01081
# [5]	valid_0's rmse: 1.00786
# [6]	valid_0's rmse: 1.00502
# [7]	valid_0's rmse: 1.00212
# [8]	valid_0's rmse: 0.999315
# [9]	valid_0's rmse: 0.996443
# [10]	valid_0's rmse: 0.993703
# [11]	valid_0's rmse: 0.990867
# [12]	valid_0's rmse: 0.988172
# [13]	valid_0's rmse: 0.985348
# [14]	valid_0's rmse: 0.982523
# [15]	valid_0's rmse: 0.979835
# [16]	valid_0's rmse: 0.977054
# [17]	valid_0's rmse: 0.974217
# [18]	valid_0's rmse: 0.97163
# [19]	valid_0's rmse: 0.968834
# [20]	valid_0's rmse: 0.966157
# [21]	valid_0's rmse: 0.963637
# [22]	valid_0's rmse: 0.960914
# [23]	valid_0's rmse: 0.95826
# [24]	valid_0's rmse: 0.955713
# [25]	valid_0's rmse: 0.953107
# [26]	valid_0's rmse: 0.950546
# [27]	valid_0's rmse: 0.948089
# [28]	valid_0's rmse: 0.945488
# [29]	valid_0's rmse: 0.943047
# [30]	valid_0's rmse: 0.940552
# [31]	valid_0's rmse: 0.93813
# [32]	valid_0's rmse: 0.935671
# [33]	valid_0's rmse: 0.933213
# [34]	valid_0's rmse: 0.930847
# [35]	valid_0's rmse: 0.92851
# [36]	valid_0's rmse: 0.92613
# [37]	valid_0's rmse: 0.923824
# [38]	valid_0's rmse: 0.921493
# [39]	valid_0's rmse: 0.919189
# [40]	valid_0's rmse: 0.916889
# [41]	valid_0's rmse: 0.914613
# [42]	valid_0's rmse: 0.912317
# [43]	valid_0's rmse: 0.910117
# [44]	valid_0's rmse: 0.9079
# [45]	valid_0's rmse: 0.905685
# [46]	valid_0's rmse: 0.903539
# [47]	valid_0's rmse: 0.901379
# [48]	valid_0's rmse: 0.899216
# [49]	valid_0's rmse: 0.897078
# [50]	valid_0's rmse: 0.894947
# [51]	valid_0's rmse: 0.89279
# [52]	valid_0's rmse: 0.890641
# [53]	valid_0's rmse: 0.888477
# [54]	valid_0's rmse: 0.886382
# [55]	valid_0's rmse: 0.884298
# [56]	valid_0's rmse: 0.882211
# [57]	valid_0's rmse: 0.88017
# [58]	valid_0's rmse: 0.878076
# [59]	valid_0's rmse: 0.876084
# [60]	valid_0's rmse: 0.874072
# [61]	valid_0's rmse: 0.872097
# [62]	valid_0's rmse: 0.870031
# [63]	valid_0's rmse: 0.868081
# [64]	valid_0's rmse: 0.866128
# [65]	valid_0's rmse: 0.864131
# [66]	valid_0's rmse: 0.862146
# [67]	valid_0's rmse: 0.860294
# [68]	valid_0's rmse: 0.858366
# [69]	valid_0's rmse: 0.85645
# [70]	valid_0's rmse: 0.854576
# [71]	valid_0's rmse: 0.852704
# [72]	valid_0's rmse: 0.850815
# [73]	valid_0's rmse: 0.848937
# [74]	valid_0's rmse: 0.847061
# [75]	valid_0's rmse: 0.845201
# [76]	valid_0's rmse: 0.843475
# [77]	valid_0's rmse: 0.841662
# [78]	valid_0's rmse: 0.839858
# [79]	valid_0's rmse: 0.838111
# [80]	valid_0's rmse: 0.836334
# [81]	valid_0's rmse: 0.834569
# [82]	valid_0's rmse: 0.832844
# [83]	valid_0's rmse: 0.831145
# [84]	valid_0's rmse: 0.82946
# [85]	valid_0's rmse: 0.827749
# [86]	valid_0's rmse: 0.826096
# [87]	valid_0's rmse: 0.824424
# [88]	valid_0's rmse: 0.822856
# [89]	valid_0's rmse: 0.821221
# [90]	valid_0's rmse: 0.819644
# [91]	valid_0's rmse: 0.818036
# [92]	valid_0's rmse: 0.816505
# [93]	valid_0's rmse: 0.814906
# [94]	valid_0's rmse: 0.813383
# [95]	valid_0's rmse: 0.81191
# [96]	valid_0's rmse: 0.810355
# [97]	valid_0's rmse: 0.808814
# [98]	valid_0's rmse: 0.807354
# [99]	valid_0's rmse: 0.805805
# [100]	valid_0's rmse: 0.80427
# [101]	valid_0's rmse: 0.802787
# [102]	valid_0's rmse: 0.801262
# [103]	valid_0's rmse: 0.799848
# [104]	valid_0's rmse: 0.798327
# [105]	valid_0's rmse: 0.796837
# [106]	valid_0's rmse: 0.795367
# [107]	valid_0's rmse: 0.793903
# [108]	valid_0's rmse: 0.792473
# [109]	valid_0's rmse: 0.790977
# [110]	valid_0's rmse: 0.789578
# [111]	valid_0's rmse: 0.788171
# [112]	valid_0's rmse: 0.786706
# [113]	valid_0's rmse: 0.785293
# [114]	valid_0's rmse: 0.78393
# [115]	valid_0's rmse: 0.782533
# [116]	valid_0's rmse: 0.781115
# [117]	valid_0's rmse: 0.779771
# [118]	valid_0's rmse: 0.778376
# [119]	valid_0's rmse: 0.776951
# [120]	valid_0's rmse: 0.775566
# [121]	valid_0's rmse: 0.774158
# [122]	valid_0's rmse: 0.772902
# [123]	valid_0's rmse: 0.771527
# [124]	valid_0's rmse: 0.770288
# [125]	valid_0's rmse: 0.768935
# [126]	valid_0's rmse: 0.767694
# [127]	valid_0's rmse: 0.766356
# [128]	valid_0's rmse: 0.765183
# [129]	valid_0's rmse: 0.764026
# [130]	valid_0's rmse: 0.762813
# [131]	valid_0's rmse: 0.761486
# [132]	valid_0's rmse: 0.760302
# [133]	valid_0's rmse: 0.759105
# [134]	valid_0's rmse: 0.757962
# [135]	valid_0's rmse: 0.75666
# [136]	valid_0's rmse: 0.755491
# [137]	valid_0's rmse: 0.754357
# [138]	valid_0's rmse: 0.753058
# [139]	valid_0's rmse: 0.751996
# [140]	valid_0's rmse: 0.750896
# [141]	valid_0's rmse: 0.749652
# [142]	valid_0's rmse: 0.748561
# [143]	valid_0's rmse: 0.747458
# [144]	valid_0's rmse: 0.746206
# [145]	valid_0's rmse: 0.744969
# [146]	valid_0's rmse: 0.743905
# [147]	valid_0's rmse: 0.742852
# [148]	valid_0's rmse: 0.741662
# [149]	valid_0's rmse: 0.740462
# [150]	valid_0's rmse: 0.739393
# [151]	valid_0's rmse: 0.738287
# [152]	valid_0's rmse: 0.737354
# [153]	valid_0's rmse: 0.736359
# [154]	valid_0's rmse: 0.735237
# [155]	valid_0's rmse: 0.734303
# [156]	valid_0's rmse: 0.733219
# [157]	valid_0's rmse: 0.732272
# [158]	valid_0's rmse: 0.73131
# [159]	valid_0's rmse: 0.730196
# [160]	valid_0's rmse: 0.729328
# [161]	valid_0's rmse: 0.728278
# [162]	valid_0's rmse: 0.727423
# [163]	valid_0's rmse: 0.726497
# [164]	valid_0's rmse: 0.725582
# [165]	valid_0's rmse: 0.724636
# [166]	valid_0's rmse: 0.723754
# [167]	valid_0's rmse: 0.722835
# [168]	valid_0's rmse: 0.721818
# [169]	valid_0's rmse: 0.720913
# [170]	valid_0's rmse: 0.720089
# [171]	valid_0's rmse: 0.719189
# [172]	valid_0's rmse: 0.718237
# [173]	valid_0's rmse: 0.717372
# [174]	valid_0's rmse: 0.716533
# [175]	valid_0's rmse: 0.71567
# [176]	valid_0's rmse: 0.714828
# [177]	valid_0's rmse: 0.714023
# [178]	valid_0's rmse: 0.713067
# [179]	valid_0's rmse: 0.712214
# [180]	valid_0's rmse: 0.711471
# [181]	valid_0's rmse: 0.710715
# [182]	valid_0's rmse: 0.709896
# [183]	valid_0's rmse: 0.709157
# [184]	valid_0's rmse: 0.708313
# [185]	valid_0's rmse: 0.707541
# [186]	valid_0's rmse: 0.706816
# [187]	valid_0's rmse: 0.706046
# [188]	valid_0's rmse: 0.705311
# [189]	valid_0's rmse: 0.70457
# [190]	valid_0's rmse: 0.703794
# [191]	valid_0's rmse: 0.703029
# [192]	valid_0's rmse: 0.702383
# [193]	valid_0's rmse: 0.70173
# [194]	valid_0's rmse: 0.700973
# [195]	valid_0's rmse: 0.7003
# [196]	valid_0's rmse: 0.699574
# [197]	valid_0's rmse: 0.698905
# [198]	valid_0's rmse: 0.69821
# [199]	valid_0's rmse: 0.697505
# [200]	valid_0's rmse: 0.696789
# [201]	valid_0's rmse: 0.696181
# [202]	valid_0's rmse: 0.695439
# [203]	valid_0's rmse: 0.694723
# [204]	valid_0's rmse: 0.694094
# [205]	valid_0's rmse: 0.693378
# [206]	valid_0's rmse: 0.692679
# [207]	valid_0's rmse: 0.692037
# [208]	valid_0's rmse: 0.691353
# [209]	valid_0's rmse: 0.690702
# [210]	valid_0's rmse: 0.690076
# [211]	valid_0's rmse: 0.689454
# [212]	valid_0's rmse: 0.688827
# [213]	valid_0's rmse: 0.688216
# [214]	valid_0's rmse: 0.687543
# [215]	valid_0's rmse: 0.686939
# [216]	valid_0's rmse: 0.686257
# [217]	valid_0's rmse: 0.685569
# [218]	valid_0's rmse: 0.684933
# [219]	valid_0's rmse: 0.684175
# [220]	valid_0's rmse: 0.68364
# [221]	valid_0's rmse: 0.682927
# [222]	valid_0's rmse: 0.682316
# [223]	valid_0's rmse: 0.681738
# [224]	valid_0's rmse: 0.68109
# [225]	valid_0's rmse: 0.680498
# [226]	valid_0's rmse: 0.679905
# [227]	valid_0's rmse: 0.679329
# [228]	valid_0's rmse: 0.678688
# [229]	valid_0's rmse: 0.678031
# [230]	valid_0's rmse: 0.677493
# [231]	valid_0's rmse: 0.676954
# [232]	valid_0's rmse: 0.676295
# [233]	valid_0's rmse: 0.67575
# [234]	valid_0's rmse: 0.675155
# [235]	valid_0's rmse: 0.674634
# [236]	valid_0's rmse: 0.674105
# [237]	valid_0's rmse: 0.673544
# [238]	valid_0's rmse: 0.672911
# [239]	valid_0's rmse: 0.672408
# [240]	valid_0's rmse: 0.671835
# [241]	valid_0's rmse: 0.671343
# [242]	valid_0's rmse: 0.670671
# [243]	valid_0's rmse: 0.670168
# [244]	valid_0's rmse: 0.669691
# [245]	valid_0's rmse: 0.669216
# [246]	valid_0's rmse: 0.668574
# [247]	valid_0's rmse: 0.667973
# [248]	valid_0's rmse: 0.66748
# [249]	valid_0's rmse: 0.666989
# [250]	valid_0's rmse: 0.66641
# [251]	valid_0's rmse: 0.666001
# [252]	valid_0's rmse: 0.665451
# [253]	valid_0's rmse: 0.665039
# [254]	valid_0's rmse: 0.664569
# [255]	valid_0's rmse: 0.664015
# [256]	valid_0's rmse: 0.663636
# [257]	valid_0's rmse: 0.663103
# [258]	valid_0's rmse: 0.66271
# [259]	valid_0's rmse: 0.662337
# [260]	valid_0's rmse: 0.661789
# [261]	valid_0's rmse: 0.661417
# [262]	valid_0's rmse: 0.661009
# [263]	valid_0's rmse: 0.660573
# [264]	valid_0's rmse: 0.660057
# [265]	valid_0's rmse: 0.659677
# [266]	valid_0's rmse: 0.659308
# [267]	valid_0's rmse: 0.65884
# [268]	valid_0's rmse: 0.65833
# [269]	valid_0's rmse: 0.657995
# [270]	valid_0's rmse: 0.65762
# [271]	valid_0's rmse: 0.65709
# [272]	valid_0's rmse: 0.656679
# [273]	valid_0's rmse: 0.656263
# [274]	valid_0's rmse: 0.655917
# [275]	valid_0's rmse: 0.655619
# [276]	valid_0's rmse: 0.65522
# [277]	valid_0's rmse: 0.654814
# [278]	valid_0's rmse: 0.654375
# [279]	valid_0's rmse: 0.654076
# [280]	valid_0's rmse: 0.653638
# [281]	valid_0's rmse: 0.653279
# [282]	valid_0's rmse: 0.652947
# [283]	valid_0's rmse: 0.652533
# [284]	valid_0's rmse: 0.652121
# [285]	valid_0's rmse: 0.651773
# [286]	valid_0's rmse: 0.651391
# [287]	valid_0's rmse: 0.651042
# [288]	valid_0's rmse: 0.650622
# [289]	valid_0's rmse: 0.650253
# [290]	valid_0's rmse: 0.649945
# [291]	valid_0's rmse: 0.649539
# [292]	valid_0's rmse: 0.649123
# [293]	valid_0's rmse: 0.648721
# [294]	valid_0's rmse: 0.64845
# [295]	valid_0's rmse: 0.648049
# [296]	valid_0's rmse: 0.647703
# [297]	valid_0's rmse: 0.647311
# [298]	valid_0's rmse: 0.647035
# [299]	valid_0's rmse: 0.646659
# [300]	valid_0's rmse: 0.646299
# [301]	valid_0's rmse: 0.645919
# [302]	valid_0's rmse: 0.645695
# [303]	valid_0's rmse: 0.645345
# [304]	valid_0's rmse: 0.645029
# [305]	valid_0's rmse: 0.644674
# [306]	valid_0's rmse: 0.644318
# [307]	valid_0's rmse: 0.644099
# [308]	valid_0's rmse: 0.643749
# [309]	valid_0's rmse: 0.643421
# [310]	valid_0's rmse: 0.64309
# [311]	valid_0's rmse: 0.642741
# [312]	valid_0's rmse: 0.642557
# [313]	valid_0's rmse: 0.642245
# [314]	valid_0's rmse: 0.64199
# [315]	valid_0's rmse: 0.641674
# [316]	valid_0's rmse: 0.641363
# [317]	valid_0's rmse: 0.641066
# [318]	valid_0's rmse: 0.640821
# [319]	valid_0's rmse: 0.640485
# [320]	valid_0's rmse: 0.640226
# [321]	valid_0's rmse: 0.639915
# [322]	valid_0's rmse: 0.639543
# [323]	valid_0's rmse: 0.639222
# [324]	valid_0's rmse: 0.638882
# [325]	valid_0's rmse: 0.638519
# [326]	valid_0's rmse: 0.638234
# [327]	valid_0's rmse: 0.637928
# [328]	valid_0's rmse: 0.637635
# [329]	valid_0's rmse: 0.637294
# [330]	valid_0's rmse: 0.636971
# [331]	valid_0's rmse: 0.636691
# [332]	valid_0's rmse: 0.636477
# [333]	valid_0's rmse: 0.636207
# [334]	valid_0's rmse: 0.635881
# [335]	valid_0's rmse: 0.635632
# [336]	valid_0's rmse: 0.635391
# [337]	valid_0's rmse: 0.635063
# [338]	valid_0's rmse: 0.634804
# [339]	valid_0's rmse: 0.634591
# [340]	valid_0's rmse: 0.634349
# [341]	valid_0's rmse: 0.634073
# [342]	valid_0's rmse: 0.633786
# [343]	valid_0's rmse: 0.633485
# [344]	valid_0's rmse: 0.633204
# [345]	valid_0's rmse: 0.632962
# [346]	valid_0's rmse: 0.63272
# [347]	valid_0's rmse: 0.632487
# [348]	valid_0's rmse: 0.632222
# [349]	valid_0's rmse: 0.631951
# [350]	valid_0's rmse: 0.631751
# [351]	valid_0's rmse: 0.63148
# [352]	valid_0's rmse: 0.631208
# [353]	valid_0's rmse: 0.631018
# [354]	valid_0's rmse: 0.630827
# [355]	valid_0's rmse: 0.630555
# [356]	valid_0's rmse: 0.630372
# [357]	valid_0's rmse: 0.630189
# [358]	valid_0's rmse: 0.630064
# [359]	valid_0's rmse: 0.629801
# [360]	valid_0's rmse: 0.629626
# [361]	valid_0's rmse: 0.629479
# [362]	valid_0's rmse: 0.629316
# [363]	valid_0's rmse: 0.629127
# [364]	valid_0's rmse: 0.628972
# [365]	valid_0's rmse: 0.628702
# [366]	valid_0's rmse: 0.628497
# [367]	valid_0's rmse: 0.628352
# [368]	valid_0's rmse: 0.628127
# [369]	valid_0's rmse: 0.627904
# [370]	valid_0's rmse: 0.627693
# [371]	valid_0's rmse: 0.627499
# [372]	valid_0's rmse: 0.62736
# [373]	valid_0's rmse: 0.627201
# [374]	valid_0's rmse: 0.627115
# [375]	valid_0's rmse: 0.626937
# [376]	valid_0's rmse: 0.626722
# [377]	valid_0's rmse: 0.626565
# [378]	valid_0's rmse: 0.626436
# [379]	valid_0's rmse: 0.626324
# [380]	valid_0's rmse: 0.626136
# [381]	valid_0's rmse: 0.625942
# [382]	valid_0's rmse: 0.625775
# [383]	valid_0's rmse: 0.625586
# [384]	valid_0's rmse: 0.625383
# [385]	valid_0's rmse: 0.625204
# [386]	valid_0's rmse: 0.625107
# [387]	valid_0's rmse: 0.624917
# [388]	valid_0's rmse: 0.624775
# [389]	valid_0's rmse: 0.624646
# [390]	valid_0's rmse: 0.624474
# [391]	valid_0's rmse: 0.624297
# [392]	valid_0's rmse: 0.624148
# [393]	valid_0's rmse: 0.623941
# [394]	valid_0's rmse: 0.623796
# [395]	valid_0's rmse: 0.623507
# [396]	valid_0's rmse: 0.623354
# [397]	valid_0's rmse: 0.623068
# [398]	valid_0's rmse: 0.622909
# [399]	valid_0's rmse: 0.622694
# [400]	valid_0's rmse: 0.622607
# [401]	valid_0's rmse: 0.622419
# [402]	valid_0's rmse: 0.622303
# [403]	valid_0's rmse: 0.622215
# [404]	valid_0's rmse: 0.622029
# [405]	valid_0's rmse: 0.621966
# [406]	valid_0's rmse: 0.621843
# [407]	valid_0's rmse: 0.621623
# [408]	valid_0's rmse: 0.621493
# [409]	valid_0's rmse: 0.621328
# [410]	valid_0's rmse: 0.62107
# [411]	valid_0's rmse: 0.620907
# [412]	valid_0's rmse: 0.620743
# [413]	valid_0's rmse: 0.620537
# [414]	valid_0's rmse: 0.620311
# [415]	valid_0's rmse: 0.620178
# [416]	valid_0's rmse: 0.619979
# [417]	valid_0's rmse: 0.619884
# [418]	valid_0's rmse: 0.619728
# [419]	valid_0's rmse: 0.619568
# [420]	valid_0's rmse: 0.619375
# [421]	valid_0's rmse: 0.619268
# [422]	valid_0's rmse: 0.619202
# [423]	valid_0's rmse: 0.619066
# [424]	valid_0's rmse: 0.618896
# [425]	valid_0's rmse: 0.618859
# [426]	valid_0's rmse: 0.618751
# [427]	valid_0's rmse: 0.618561
# [428]	valid_0's rmse: 0.618389
# [429]	valid_0's rmse: 0.61829
# [430]	valid_0's rmse: 0.618192
# [431]	valid_0's rmse: 0.618039
# [432]	valid_0's rmse: 0.617929
# [433]	valid_0's rmse: 0.617829
# [434]	valid_0's rmse: 0.617721
# [435]	valid_0's rmse: 0.617539
# [436]	valid_0's rmse: 0.617433
# [437]	valid_0's rmse: 0.617388
# [438]	valid_0's rmse: 0.617245
# [439]	valid_0's rmse: 0.617115
# [440]	valid_0's rmse: 0.617
# [441]	valid_0's rmse: 0.61684
# [442]	valid_0's rmse: 0.616726
# [443]	valid_0's rmse: 0.616592
# [444]	valid_0's rmse: 0.616481
# [445]	valid_0's rmse: 0.616433
# [446]	valid_0's rmse: 0.61631
# [447]	valid_0's rmse: 0.616211
# [448]	valid_0's rmse: 0.616112
# [449]	valid_0's rmse: 0.616009
# [450]	valid_0's rmse: 0.615905
# [451]	valid_0's rmse: 0.615782
# [452]	valid_0's rmse: 0.615724
# [453]	valid_0's rmse: 0.615632
# [454]	valid_0's rmse: 0.615547
# [455]	valid_0's rmse: 0.615463
# [456]	valid_0's rmse: 0.615337
# [457]	valid_0's rmse: 0.61525
# [458]	valid_0's rmse: 0.615177
# [459]	valid_0's rmse: 0.615084
# [460]	valid_0's rmse: 0.614899
# [461]	valid_0's rmse: 0.614812
# [462]	valid_0's rmse: 0.614784
# [463]	valid_0's rmse: 0.614675
# [464]	valid_0's rmse: 0.61459
# [465]	valid_0's rmse: 0.614453
# [466]	valid_0's rmse: 0.614367
# [467]	valid_0's rmse: 0.614188
# [468]	valid_0's rmse: 0.614069
# [469]	valid_0's rmse: 0.613905
# [470]	valid_0's rmse: 0.613779
# [471]	valid_0's rmse: 0.613716
# [472]	valid_0's rmse: 0.61354
# [473]	valid_0's rmse: 0.613416
# [474]	valid_0's rmse: 0.613306
# [475]	valid_0's rmse: 0.613227
# [476]	valid_0's rmse: 0.613071
# [477]	valid_0's rmse: 0.612993
# [478]	valid_0's rmse: 0.612854
# [479]	valid_0's rmse: 0.612768
# [480]	valid_0's rmse: 0.61265
# [481]	valid_0's rmse: 0.612543
# [482]	valid_0's rmse: 0.612407
# [483]	valid_0's rmse: 0.612325
# [484]	valid_0's rmse: 0.612214
# [485]	valid_0's rmse: 0.612096
# [486]	valid_0's rmse: 0.611996
# [487]	valid_0's rmse: 0.611867
# [488]	valid_0's rmse: 0.611799
# [489]	valid_0's rmse: 0.611752
# [490]	valid_0's rmse: 0.611622
# [491]	valid_0's rmse: 0.61151
# [492]	valid_0's rmse: 0.611421
# [493]	valid_0's rmse: 0.611392
# [494]	valid_0's rmse: 0.611282
# [495]	valid_0's rmse: 0.611168
# [496]	valid_0's rmse: 0.611047
# [497]	valid_0's rmse: 0.610919
# [498]	valid_0's rmse: 0.610834
# [499]	valid_0's rmse: 0.610721
# [500]	valid_0's rmse: 0.610573
# [501]	valid_0's rmse: 0.610521
# [502]	valid_0's rmse: 0.610474
# [503]	valid_0's rmse: 0.610378
# [504]	valid_0's rmse: 0.610268
# [505]	valid_0's rmse: 0.610185
# [506]	valid_0's rmse: 0.610133
# [507]	valid_0's rmse: 0.610016
# [508]	valid_0's rmse: 0.609979
# [509]	valid_0's rmse: 0.609877
# [510]	valid_0's rmse: 0.609786
# [511]	valid_0's rmse: 0.609764
# [512]	valid_0's rmse: 0.609685
# [513]	valid_0's rmse: 0.609567
# [514]	valid_0's rmse: 0.609461
# [515]	valid_0's rmse: 0.609361
# [516]	valid_0's rmse: 0.609266
# [517]	valid_0's rmse: 0.609242
# [518]	valid_0's rmse: 0.609121
# [519]	valid_0's rmse: 0.60901
# [520]	valid_0's rmse: 0.608937
# [521]	valid_0's rmse: 0.608827
# [522]	valid_0's rmse: 0.608727
# [523]	valid_0's rmse: 0.608621
# [524]	valid_0's rmse: 0.608521
# [525]	valid_0's rmse: 0.608454
# [526]	valid_0's rmse: 0.608359
# [527]	valid_0's rmse: 0.608257
# [528]	valid_0's rmse: 0.60814
# [529]	valid_0's rmse: 0.608052
# [530]	valid_0's rmse: 0.607953
# [531]	valid_0's rmse: 0.607892
# [532]	valid_0's rmse: 0.607835
# [533]	valid_0's rmse: 0.607753
# [534]	valid_0's rmse: 0.607718
# [535]	valid_0's rmse: 0.607605
# [536]	valid_0's rmse: 0.607556
# [537]	valid_0's rmse: 0.607473
# [538]	valid_0's rmse: 0.607461
# [539]	valid_0's rmse: 0.607389
# [540]	valid_0's rmse: 0.607353
# [541]	valid_0's rmse: 0.607246
# [542]	valid_0's rmse: 0.607223
# [543]	valid_0's rmse: 0.60714
# [544]	valid_0's rmse: 0.607065
# [545]	valid_0's rmse: 0.607
# [546]	valid_0's rmse: 0.606986
# [547]	valid_0's rmse: 0.606893
# [548]	valid_0's rmse: 0.606821
# [549]	valid_0's rmse: 0.606812
# [550]	valid_0's rmse: 0.606687
# [551]	valid_0's rmse: 0.606683
# [552]	valid_0's rmse: 0.606639
# [553]	valid_0's rmse: 0.606563
# [554]	valid_0's rmse: 0.60651
# [555]	valid_0's rmse: 0.606414
# [556]	valid_0's rmse: 0.606346
# [557]	valid_0's rmse: 0.606227
# [558]	valid_0's rmse: 0.60619
# [559]	valid_0's rmse: 0.606131
# [560]	valid_0's rmse: 0.60607
# [561]	valid_0's rmse: 0.605994
# [562]	valid_0's rmse: 0.605953
# [563]	valid_0's rmse: 0.605867
# [564]	valid_0's rmse: 0.605766
# [565]	valid_0's rmse: 0.605702
# [566]	valid_0's rmse: 0.605662
# [567]	valid_0's rmse: 0.605571
# [568]	valid_0's rmse: 0.605517
# [569]	valid_0's rmse: 0.605432
# [570]	valid_0's rmse: 0.605374
# [571]	valid_0's rmse: 0.605304
# [572]	valid_0's rmse: 0.605213
# [573]	valid_0's rmse: 0.605143
# [574]	valid_0's rmse: 0.605059
# [575]	valid_0's rmse: 0.604989
# [576]	valid_0's rmse: 0.604927
# [577]	valid_0's rmse: 0.604864
# [578]	valid_0's rmse: 0.604796
# [579]	valid_0's rmse: 0.604732
# [580]	valid_0's rmse: 0.604664
# [581]	valid_0's rmse: 0.604665
# [582]	valid_0's rmse: 0.604645
# [583]	valid_0's rmse: 0.604624
# [584]	valid_0's rmse: 0.604558
# [585]	valid_0's rmse: 0.604472
# [586]	valid_0's rmse: 0.604391
# [587]	valid_0's rmse: 0.604325
# [588]	valid_0's rmse: 0.604242
# [589]	valid_0's rmse: 0.604213
# [590]	valid_0's rmse: 0.604165
# [591]	valid_0's rmse: 0.604103
# [592]	valid_0's rmse: 0.604017
# [593]	valid_0's rmse: 0.604024
# [594]	valid_0's rmse: 0.60404
# [595]	valid_0's rmse: 0.604062
# [596]	valid_0's rmse: 0.604067
# [597]	valid_0's rmse: 0.604053
# [598]	valid_0's rmse: 0.604002
# [599]	valid_0's rmse: 0.603994
# [600]	valid_0's rmse: 0.603956
# [601]	valid_0's rmse: 0.6039
# [602]	valid_0's rmse: 0.603874
# [603]	valid_0's rmse: 0.603875
# [604]	valid_0's rmse: 0.603813
# [605]	valid_0's rmse: 0.603766
# [606]	valid_0's rmse: 0.603772
# [607]	valid_0's rmse: 0.603737
# [608]	valid_0's rmse: 0.603716
# [609]	valid_0's rmse: 0.603673
# [610]	valid_0's rmse: 0.603608
# [611]	valid_0's rmse: 0.603601
# [612]	valid_0's rmse: 0.603603
# [613]	valid_0's rmse: 0.603625
# [614]	valid_0's rmse: 0.603627
# [615]	valid_0's rmse: 0.603618
# [616]	valid_0's rmse: 0.603588
# [617]	valid_0's rmse: 0.603586
# [618]	valid_0's rmse: 0.60359
# [619]	valid_0's rmse: 0.603641
# [620]	valid_0's rmse: 0.603634
# [621]	valid_0's rmse: 0.603646
# [622]	valid_0's rmse: 0.603635
# [623]	valid_0's rmse: 0.603636
# [624]	valid_0's rmse: 0.603624
# [625]	valid_0's rmse: 0.603638
# [626]	valid_0's rmse: 0.603648
# [627]	valid_0's rmse: 0.60367
# [628]	valid_0's rmse: 0.603663
# [629]	valid_0's rmse: 0.603682
# [630]	valid_0's rmse: 0.603729
# [631]	valid_0's rmse: 0.60377
# [632]	valid_0's rmse: 0.603761
# [633]	valid_0's rmse: 0.603691
# [634]	valid_0's rmse: 0.603618
# [635]	valid_0's rmse: 0.603549
# [636]	valid_0's rmse: 0.603476
# [637]	valid_0's rmse: 0.603472
# [638]	valid_0's rmse: 0.603425
# [639]	valid_0's rmse: 0.603404
# [640]	valid_0's rmse: 0.603393
# [641]	valid_0's rmse: 0.603348
# [642]	valid_0's rmse: 0.603315
# [643]	valid_0's rmse: 0.603278
# [644]	valid_0's rmse: 0.603295
# [645]	valid_0's rmse: 0.603294
# [646]	valid_0's rmse: 0.603226
# [647]	valid_0's rmse: 0.603192
# [648]	valid_0's rmse: 0.603124
# [649]	valid_0's rmse: 0.603086
# [650]	valid_0's rmse: 0.603102
# [651]	valid_0's rmse: 0.603
# [652]	valid_0's rmse: 0.602958
# [653]	valid_0's rmse: 0.602956
# [654]	valid_0's rmse: 0.602934
# [655]	valid_0's rmse: 0.602893
# [656]	valid_0's rmse: 0.602918
# [657]	valid_0's rmse: 0.602855
# [658]	valid_0's rmse: 0.60283
# [659]	valid_0's rmse: 0.602788
# [660]	valid_0's rmse: 0.602755
# [661]	valid_0's rmse: 0.602721
# [662]	valid_0's rmse: 0.602687
# [663]	valid_0's rmse: 0.602658
# [664]	valid_0's rmse: 0.602707
# [665]	valid_0's rmse: 0.602709
# [666]	valid_0's rmse: 0.602698
# [667]	valid_0's rmse: 0.602683
# [668]	valid_0's rmse: 0.602657
# [669]	valid_0's rmse: 0.602656
# [670]	valid_0's rmse: 0.602658
# [671]	valid_0's rmse: 0.602628
# [672]	valid_0's rmse: 0.602642
# [673]	valid_0's rmse: 0.602643
# [674]	valid_0's rmse: 0.602643
# [675]	valid_0's rmse: 0.602603
# [676]	valid_0's rmse: 0.602557
# [677]	valid_0's rmse: 0.602589
# [678]	valid_0's rmse: 0.60259
# [679]	valid_0's rmse: 0.602592
# [680]	valid_0's rmse: 0.602589
# [681]	valid_0's rmse: 0.602551
# [682]	valid_0's rmse: 0.602551
# [683]	valid_0's rmse: 0.602525
# [684]	valid_0's rmse: 0.602531
# [685]	valid_0's rmse: 0.60261
# [686]	valid_0's rmse: 0.602596
# [687]	valid_0's rmse: 0.602559
# [688]	valid_0's rmse: 0.602625
# [689]	valid_0's rmse: 0.602627
# [690]	valid_0's rmse: 0.602636
# [691]	valid_0's rmse: 0.602624
# [692]	valid_0's rmse: 0.602589
# [693]	valid_0's rmse: 0.602642
# [694]	valid_0's rmse: 0.602619
# [695]	valid_0's rmse: 0.60261
# [696]	valid_0's rmse: 0.602577
# [697]	valid_0's rmse: 0.602553
# [698]	valid_0's rmse: 0.602558
# [699]	valid_0's rmse: 0.602572
# [700]	valid_0's rmse: 0.602598
# [701]	valid_0's rmse: 0.602543
# [702]	valid_0's rmse: 0.602516
# [703]	valid_0's rmse: 0.602576
# [704]	valid_0's rmse: 0.602558
# [705]	valid_0's rmse: 0.602543
# [706]	valid_0's rmse: 0.602532
# [707]	valid_0's rmse: 0.602489
# [708]	valid_0's rmse: 0.602518
# [709]	valid_0's rmse: 0.602439
# [710]	valid_0's rmse: 0.602448
# [711]	valid_0's rmse: 0.602504
# [712]	valid_0's rmse: 0.602497
# [713]	valid_0's rmse: 0.602564
# [714]	valid_0's rmse: 0.602543
# [715]	valid_0's rmse: 0.602579
# [716]	valid_0's rmse: 0.602588
# [717]	valid_0's rmse: 0.602587
# [718]	valid_0's rmse: 0.602569
# [719]	valid_0's rmse: 0.602564
# [720]	valid_0's rmse: 0.60258
# [721]	valid_0's rmse: 0.602542
# [722]	valid_0's rmse: 0.602467
# [723]	valid_0's rmse: 0.602478
# [724]	valid_0's rmse: 0.602539
# [725]	valid_0's rmse: 0.602543
# [726]	valid_0's rmse: 0.602481
# [727]	valid_0's rmse: 0.602493
# [728]	valid_0's rmse: 0.602485
# [729]	valid_0's rmse: 0.602481
# [730]	valid_0's rmse: 0.602444
# [731]	valid_0's rmse: 0.602436
# [732]	valid_0's rmse: 0.6024
# [733]	valid_0's rmse: 0.602382
# [734]	valid_0's rmse: 0.602452
# [735]	valid_0's rmse: 0.602449
# [736]	valid_0's rmse: 0.602442
# [737]	valid_0's rmse: 0.602477
# [738]	valid_0's rmse: 0.60252
# [739]	valid_0's rmse: 0.602542
# [740]	valid_0's rmse: 0.602585
# [741]	valid_0's rmse: 0.602561
# [742]	valid_0's rmse: 0.602552
# [743]	valid_0's rmse: 0.602605
# [744]	valid_0's rmse: 0.602533
# [745]	valid_0's rmse: 0.602516
# [746]	valid_0's rmse: 0.6025
# [747]	valid_0's rmse: 0.60249
# [748]	valid_0's rmse: 0.602514
# [749]	valid_0's rmse: 0.602506
# [750]	valid_0's rmse: 0.602529
# [751]	valid_0's rmse: 0.60258
# [752]	valid_0's rmse: 0.602627
# [753]	valid_0's rmse: 0.602601
# [754]	valid_0's rmse: 0.602586
# [755]	valid_0's rmse: 0.602617
# [756]	valid_0's rmse: 0.602628
# [757]	valid_0's rmse: 0.602587
# [758]	valid_0's rmse: 0.602587
# [759]	valid_0's rmse: 0.602542
# [760]	valid_0's rmse: 0.602602
# [761]	valid_0's rmse: 0.602609
# [762]	valid_0's rmse: 0.602634
# [763]	valid_0's rmse: 0.602578
# [764]	valid_0's rmse: 0.602491
# [765]	valid_0's rmse: 0.602471
# [766]	valid_0's rmse: 0.602434
# [767]	valid_0's rmse: 0.602486
# [768]	valid_0's rmse: 0.602439
# [769]	valid_0's rmse: 0.602419
# [770]	valid_0's rmse: 0.602463
# [771]	valid_0's rmse: 0.60243
# [772]	valid_0's rmse: 0.602446
# [773]	valid_0's rmse: 0.602362
# [774]	valid_0's rmse: 0.602367
# [775]	valid_0's rmse: 0.602334
# [776]	valid_0's rmse: 0.602291
# [777]	valid_0's rmse: 0.602268
# [778]	valid_0's rmse: 0.602294
# [779]	valid_0's rmse: 0.602308
# [780]	valid_0's rmse: 0.602335
# [781]	valid_0's rmse: 0.602349
# [782]	valid_0's rmse: 0.60231
# [783]	valid_0's rmse: 0.602254
# [784]	valid_0's rmse: 0.602297
# [785]	valid_0's rmse: 0.602294
# [786]	valid_0's rmse: 0.602282
# [787]	valid_0's rmse: 0.602286
# [788]	valid_0's rmse: 0.602275
# [789]	valid_0's rmse: 0.602243
# [790]	valid_0's rmse: 0.602156
# [791]	valid_0's rmse: 0.602107
# [792]	valid_0's rmse: 0.602088
# [793]	valid_0's rmse: 0.602108
# [794]	valid_0's rmse: 0.602041
# [795]	valid_0's rmse: 0.602063
# [796]	valid_0's rmse: 0.602086
# [797]	valid_0's rmse: 0.60212
# [798]	valid_0's rmse: 0.602077
# [799]	valid_0's rmse: 0.602104
# [800]	valid_0's rmse: 0.602105
# [801]	valid_0's rmse: 0.60204
# [802]	valid_0's rmse: 0.602049
# [803]	valid_0's rmse: 0.602092
# [804]	valid_0's rmse: 0.602061
# [805]	valid_0's rmse: 0.602087
# [806]	valid_0's rmse: 0.602111
# [807]	valid_0's rmse: 0.602159
# [808]	valid_0's rmse: 0.60213
# [809]	valid_0's rmse: 0.602073
# [810]	valid_0's rmse: 0.60205
# [811]	valid_0's rmse: 0.602086
# [812]	valid_0's rmse: 0.602067
# [813]	valid_0's rmse: 0.602067
# [814]	valid_0's rmse: 0.602057
# [815]	valid_0's rmse: 0.602043
# [816]	valid_0's rmse: 0.602068
# [817]	valid_0's rmse: 0.602124
# [818]	valid_0's rmse: 0.602063
# [819]	valid_0's rmse: 0.601988
# [820]	valid_0's rmse: 0.601927
# [821]	valid_0's rmse: 0.601902
# [822]	valid_0's rmse: 0.601942
# [823]	valid_0's rmse: 0.601966
# [824]	valid_0's rmse: 0.601914
# [825]	valid_0's rmse: 0.601855
# [826]	valid_0's rmse: 0.60185
# [827]	valid_0's rmse: 0.60185
# [828]	valid_0's rmse: 0.601811
# [829]	valid_0's rmse: 0.601768
# [830]	valid_0's rmse: 0.601792
# [831]	valid_0's rmse: 0.601806
# [832]	valid_0's rmse: 0.601823
# [833]	valid_0's rmse: 0.601767
# [834]	valid_0's rmse: 0.601701
# [835]	valid_0's rmse: 0.60165
# [836]	valid_0's rmse: 0.601636
# [837]	valid_0's rmse: 0.601642
# [838]	valid_0's rmse: 0.601644
# [839]	valid_0's rmse: 0.601612
# [840]	valid_0's rmse: 0.601634
# [841]	valid_0's rmse: 0.601661
# [842]	valid_0's rmse: 0.601598
# [843]	valid_0's rmse: 0.601589
# [844]	valid_0's rmse: 0.601574
# [845]	valid_0's rmse: 0.601605
# [846]	valid_0's rmse: 0.60158
# [847]	valid_0's rmse: 0.60158
# [848]	valid_0's rmse: 0.60153
# [849]	valid_0's rmse: 0.601554
# [850]	valid_0's rmse: 0.601569
# [851]	valid_0's rmse: 0.601581
# [852]	valid_0's rmse: 0.601615
# [853]	valid_0's rmse: 0.601618
# [854]	valid_0's rmse: 0.601596
# [855]	valid_0's rmse: 0.601548
# [856]	valid_0's rmse: 0.60152
# [857]	valid_0's rmse: 0.601509
# [858]	valid_0's rmse: 0.601463
# [859]	valid_0's rmse: 0.601461
# [860]	valid_0's rmse: 0.601446
# [861]	valid_0's rmse: 0.60147
# [862]	valid_0's rmse: 0.601491
# [863]	valid_0's rmse: 0.601477
# [864]	valid_0's rmse: 0.601435
# [865]	valid_0's rmse: 0.601435
# [866]	valid_0's rmse: 0.601414
# [867]	valid_0's rmse: 0.601342
# [868]	valid_0's rmse: 0.601343
# [869]	valid_0's rmse: 0.601295
# [870]	valid_0's rmse: 0.601292
# [871]	valid_0's rmse: 0.601311
# [872]	valid_0's rmse: 0.60125
# [873]	valid_0's rmse: 0.601234
# [874]	valid_0's rmse: 0.601196
# [875]	valid_0's rmse: 0.601159
# [876]	valid_0's rmse: 0.601201
# [877]	valid_0's rmse: 0.601215
# [878]	valid_0's rmse: 0.60116
# [879]	valid_0's rmse: 0.601173
# [880]	valid_0's rmse: 0.601107
# [881]	valid_0's rmse: 0.601131
# [882]	valid_0's rmse: 0.601159
# [883]	valid_0's rmse: 0.601126
# [884]	valid_0's rmse: 0.601137
# [885]	valid_0's rmse: 0.601175
# [886]	valid_0's rmse: 0.601128
# [887]	valid_0's rmse: 0.601074
# [888]	valid_0's rmse: 0.601105
# [889]	valid_0's rmse: 0.601074
# [890]	valid_0's rmse: 0.601054
# [891]	valid_0's rmse: 0.601075
# [892]	valid_0's rmse: 0.601051
# [893]	valid_0's rmse: 0.601031
# [894]	valid_0's rmse: 0.601063
# [895]	valid_0's rmse: 0.601026
# [896]	valid_0's rmse: 0.600998
# [897]	valid_0's rmse: 0.600955
# [898]	valid_0's rmse: 0.600898
# [899]	valid_0's rmse: 0.600871
# [900]	valid_0's rmse: 0.600893
# [901]	valid_0's rmse: 0.600851
# [902]	valid_0's rmse: 0.600846
# [903]	valid_0's rmse: 0.600796
# [904]	valid_0's rmse: 0.600811
# [905]	valid_0's rmse: 0.600731
# [906]	valid_0's rmse: 0.60068
# [907]	valid_0's rmse: 0.600601
# [908]	valid_0's rmse: 0.60058
# [909]	valid_0's rmse: 0.600611
# [910]	valid_0's rmse: 0.600604
# [911]	valid_0's rmse: 0.600652
# [912]	valid_0's rmse: 0.600574
# [913]	valid_0's rmse: 0.600605
# [914]	valid_0's rmse: 0.600599
# [915]	valid_0's rmse: 0.600531
# [916]	valid_0's rmse: 0.60046
# [917]	valid_0's rmse: 0.60047
# [918]	valid_0's rmse: 0.600464
# [919]	valid_0's rmse: 0.600495
# [920]	valid_0's rmse: 0.600467
# [921]	valid_0's rmse: 0.600423
# [922]	valid_0's rmse: 0.600447
# [923]	valid_0's rmse: 0.600431
# [924]	valid_0's rmse: 0.600382
# [925]	valid_0's rmse: 0.600378
# [926]	valid_0's rmse: 0.600377
# [927]	valid_0's rmse: 0.60035
# [928]	valid_0's rmse: 0.600353
# [929]	valid_0's rmse: 0.600308
# [930]	valid_0's rmse: 0.600321
# [931]	valid_0's rmse: 0.600293
# [932]	valid_0's rmse: 0.600289
# [933]	valid_0's rmse: 0.600241
# [934]	valid_0's rmse: 0.600262
# [935]	valid_0's rmse: 0.600268
# [936]	valid_0's rmse: 0.600215
# [937]	valid_0's rmse: 0.600232
# [938]	valid_0's rmse: 0.600189
# [939]	valid_0's rmse: 0.600188
# [940]	valid_0's rmse: 0.600115
# [941]	valid_0's rmse: 0.600137
# [942]	valid_0's rmse: 0.600127
# [943]	valid_0's rmse: 0.600053
# [944]	valid_0's rmse: 0.600043
# [945]	valid_0's rmse: 0.600034
# [946]	valid_0's rmse: 0.600052
# [947]	valid_0's rmse: 0.600046
# [948]	valid_0's rmse: 0.600003
# [949]	valid_0's rmse: 0.600013
# [950]	valid_0's rmse: 0.599985
# [951]	valid_0's rmse: 0.599949
# [952]	valid_0's rmse: 0.599915
# [953]	valid_0's rmse: 0.599933
# [954]	valid_0's rmse: 0.599915
# [955]	valid_0's rmse: 0.599905
# [956]	valid_0's rmse: 0.599897
# [957]	valid_0's rmse: 0.599916
# [958]	valid_0's rmse: 0.599931
# [959]	valid_0's rmse: 0.599927
# [960]	valid_0's rmse: 0.599927
# [961]	valid_0's rmse: 0.599919
# [962]	valid_0's rmse: 0.59995
# [963]	valid_0's rmse: 0.599964
# [964]	valid_0's rmse: 0.599963
# [965]	valid_0's rmse: 0.599982
# [966]	valid_0's rmse: 0.600011
# [967]	valid_0's rmse: 0.600019
# [968]	valid_0's rmse: 0.600029
# [969]	valid_0's rmse: 0.600027
# [970]	valid_0's rmse: 0.600027
# [971]	valid_0's rmse: 0.600068
# [972]	valid_0's rmse: 0.600087
# [973]	valid_0's rmse: 0.600084
# [974]	valid_0's rmse: 0.600115
# [975]	valid_0's rmse: 0.600137
# [976]	valid_0's rmse: 0.600145
# [977]	valid_0's rmse: 0.600117
# [978]	valid_0's rmse: 0.60012
# [979]	valid_0's rmse: 0.600121
# [980]	valid_0's rmse: 0.600098
# [981]	valid_0's rmse: 0.600112
# [982]	valid_0's rmse: 0.60009
# [983]	valid_0's rmse: 0.600099
# [984]	valid_0's rmse: 0.600139
# [985]	valid_0's rmse: 0.60015
# [986]	valid_0's rmse: 0.600153
# [987]	valid_0's rmse: 0.600187
# [988]	valid_0's rmse: 0.600191
# [989]	valid_0's rmse: 0.600226
# [990]	valid_0's rmse: 0.600261
# [991]	valid_0's rmse: 0.600317
# [992]	valid_0's rmse: 0.60032
# [993]	valid_0's rmse: 0.600277
# [994]	valid_0's rmse: 0.600274
# [995]	valid_0's rmse: 0.6003
# [996]	valid_0's rmse: 0.600326
# [997]	valid_0's rmse: 0.600347
# [998]	valid_0's rmse: 0.600399
# [999]	valid_0's rmse: 0.600408
# [1000]	valid_0's rmse: 0.600379
# [1001]	valid_0's rmse: 0.600378
# [1002]	valid_0's rmse: 0.600389
# [1003]	valid_0's rmse: 0.600411
# [1004]	valid_0's rmse: 0.600443
# [1005]	valid_0's rmse: 0.600462
# [1006]	valid_0's rmse: 0.600459
# [1007]	valid_0's rmse: 0.600466
# [1008]	valid_0's rmse: 0.600532
# [1009]	valid_0's rmse: 0.600528
# [1010]	valid_0's rmse: 0.600542
# [1011]	valid_0's rmse: 0.600567
# [1012]	valid_0's rmse: 0.600543
# [1013]	valid_0's rmse: 0.600529
# [1014]	valid_0's rmse: 0.600524
# [1015]	valid_0's rmse: 0.60053
# [1016]	valid_0's rmse: 0.600514
# [1017]	valid_0's rmse: 0.600506
# [1018]	valid_0's rmse: 0.600507
# [1019]	valid_0's rmse: 0.600567
# [1020]	valid_0's rmse: 0.600606
# [1021]	valid_0's rmse: 0.600613
# [1022]	valid_0's rmse: 0.600657
# [1023]	valid_0's rmse: 0.600679
# [1024]	valid_0's rmse: 0.600692
# --------------------
# Fold:1:
# Feature Selection (get null_imp_df):
# Run 50 rounds of model training:
# 100%|██████████| 50/50 [03:21<00:00,  4.03s/it]
# Feature Selection (actual_imp_df):
# Run 50 rounds of model training:
# 100%|██████████| 50/50 [28:35<00:00, 34.30s/it]
# Feature Selection by Null Importances: gain:
# 100%|██████████| 9/9 [02:02<00:00, 13.58s/it]
# Feature Selection by Null Importances: split:
# 100%|██████████| 9/9 [02:05<00:00, 13.96s/it]
# Feature Selection by Null Importances: both:
# 100%|██████████| 9/9 [02:05<00:00, 13.99s/it]
# After feature selection: 165 -> 94.
# [1]	valid_0's rmse: 1.02318
# [2]	valid_0's rmse: 1.02015
# [3]	valid_0's rmse: 1.01711
# [4]	valid_0's rmse: 1.01409
# [5]	valid_0's rmse: 1.01108
# [6]	valid_0's rmse: 1.00809
# [7]	valid_0's rmse: 1.00507
# [8]	valid_0's rmse: 1.00213
# [9]	valid_0's rmse: 0.99918
# [10]	valid_0's rmse: 0.996328
# [11]	valid_0's rmse: 0.993483
# [12]	valid_0's rmse: 0.9906
# [13]	valid_0's rmse: 0.987728
# [14]	valid_0's rmse: 0.984868
# [15]	valid_0's rmse: 0.982083
# [16]	valid_0's rmse: 0.979263
# [17]	valid_0's rmse: 0.976527
# [18]	valid_0's rmse: 0.973826
# [19]	valid_0's rmse: 0.970983
# [20]	valid_0's rmse: 0.968243
# [21]	valid_0's rmse: 0.965585
# [22]	valid_0's rmse: 0.962979
# [23]	valid_0's rmse: 0.960309
# [24]	valid_0's rmse: 0.957729
# [25]	valid_0's rmse: 0.955156
# [26]	valid_0's rmse: 0.952643
# [27]	valid_0's rmse: 0.950098
# [28]	valid_0's rmse: 0.947547
# [29]	valid_0's rmse: 0.944963
# [30]	valid_0's rmse: 0.942506
# [31]	valid_0's rmse: 0.939921
# [32]	valid_0's rmse: 0.937446
# [33]	valid_0's rmse: 0.935039
# [34]	valid_0's rmse: 0.932654
# [35]	valid_0's rmse: 0.930146
# [36]	valid_0's rmse: 0.927741
# [37]	valid_0's rmse: 0.925303
# [38]	valid_0's rmse: 0.922956
# [39]	valid_0's rmse: 0.920579
# [40]	valid_0's rmse: 0.918239
# [41]	valid_0's rmse: 0.91594
# [42]	valid_0's rmse: 0.913582
# [43]	valid_0's rmse: 0.911318
# [44]	valid_0's rmse: 0.909027
# [45]	valid_0's rmse: 0.906775
# [46]	valid_0's rmse: 0.90446
# [47]	valid_0's rmse: 0.902295
# [48]	valid_0's rmse: 0.900033
# [49]	valid_0's rmse: 0.89777
# [50]	valid_0's rmse: 0.895516
# [51]	valid_0's rmse: 0.893344
# [52]	valid_0's rmse: 0.89115
# [53]	valid_0's rmse: 0.888931
# [54]	valid_0's rmse: 0.886834
# [55]	valid_0's rmse: 0.884722
# [56]	valid_0's rmse: 0.882556
# [57]	valid_0's rmse: 0.880424
# [58]	valid_0's rmse: 0.878322
# [59]	valid_0's rmse: 0.876197
# [60]	valid_0's rmse: 0.874179
# [61]	valid_0's rmse: 0.872134
# [62]	valid_0's rmse: 0.870131
# [63]	valid_0's rmse: 0.868104
# [64]	valid_0's rmse: 0.866095
# [65]	valid_0's rmse: 0.864025
# [66]	valid_0's rmse: 0.862051
# [67]	valid_0's rmse: 0.860059
# [68]	valid_0's rmse: 0.85817
# [69]	valid_0's rmse: 0.856209
# [70]	valid_0's rmse: 0.85437
# [71]	valid_0's rmse: 0.852465
# [72]	valid_0's rmse: 0.85053
# [73]	valid_0's rmse: 0.848772
# [74]	valid_0's rmse: 0.846911
# [75]	valid_0's rmse: 0.845037
# [76]	valid_0's rmse: 0.843207
# [77]	valid_0's rmse: 0.841339
# [78]	valid_0's rmse: 0.839494
# [79]	valid_0's rmse: 0.837767
# [80]	valid_0's rmse: 0.835939
# [81]	valid_0's rmse: 0.83421
# [82]	valid_0's rmse: 0.832508
# [83]	valid_0's rmse: 0.830836
# [84]	valid_0's rmse: 0.829099
# [85]	valid_0's rmse: 0.827312
# [86]	valid_0's rmse: 0.825619
# [87]	valid_0's rmse: 0.823811
# [88]	valid_0's rmse: 0.82208
# [89]	valid_0's rmse: 0.820483
# [90]	valid_0's rmse: 0.818738
# [91]	valid_0's rmse: 0.81703
# [92]	valid_0's rmse: 0.815402
# [93]	valid_0's rmse: 0.813863
# [94]	valid_0's rmse: 0.812183
# [95]	valid_0's rmse: 0.810459
# [96]	valid_0's rmse: 0.808893
# [97]	valid_0's rmse: 0.807299
# [98]	valid_0's rmse: 0.805636
# [99]	valid_0's rmse: 0.804134
# [100]	valid_0's rmse: 0.802515
# [101]	valid_0's rmse: 0.801005
# [102]	valid_0's rmse: 0.799382
# [103]	valid_0's rmse: 0.797803
# [104]	valid_0's rmse: 0.796287
# [105]	valid_0's rmse: 0.794817
# [106]	valid_0's rmse: 0.793257
# [107]	valid_0's rmse: 0.791744
# [108]	valid_0's rmse: 0.790309
# [109]	valid_0's rmse: 0.788827
# [110]	valid_0's rmse: 0.787271
# [111]	valid_0's rmse: 0.785843
# [112]	valid_0's rmse: 0.784368
# [113]	valid_0's rmse: 0.782964
# [114]	valid_0's rmse: 0.781583
# [115]	valid_0's rmse: 0.780164
# [116]	valid_0's rmse: 0.778753
# [117]	valid_0's rmse: 0.77732
# [118]	valid_0's rmse: 0.775884
# [119]	valid_0's rmse: 0.774549
# [120]	valid_0's rmse: 0.773168
# [121]	valid_0's rmse: 0.771824
# [122]	valid_0's rmse: 0.770527
# [123]	valid_0's rmse: 0.769124
# [124]	valid_0's rmse: 0.767753
# [125]	valid_0's rmse: 0.766508
# [126]	valid_0's rmse: 0.765196
# [127]	valid_0's rmse: 0.763846
# [128]	valid_0's rmse: 0.762632
# [129]	valid_0's rmse: 0.761349
# [130]	valid_0's rmse: 0.760062
# [131]	valid_0's rmse: 0.758857
# [132]	valid_0's rmse: 0.757612
# [133]	valid_0's rmse: 0.756448
# [134]	valid_0's rmse: 0.755247
# [135]	valid_0's rmse: 0.754017
# [136]	valid_0's rmse: 0.752831
# [137]	valid_0's rmse: 0.751689
# [138]	valid_0's rmse: 0.750529
# [139]	valid_0's rmse: 0.749315
# [140]	valid_0's rmse: 0.748161
# [141]	valid_0's rmse: 0.746961
# [142]	valid_0's rmse: 0.74582
# [143]	valid_0's rmse: 0.744668
# [144]	valid_0's rmse: 0.743558
# [145]	valid_0's rmse: 0.742428
# [146]	valid_0's rmse: 0.741331
# [147]	valid_0's rmse: 0.740254
# [148]	valid_0's rmse: 0.739153
# [149]	valid_0's rmse: 0.738078
# [150]	valid_0's rmse: 0.737025
# [151]	valid_0's rmse: 0.735945
# [152]	valid_0's rmse: 0.735005
# [153]	valid_0's rmse: 0.734005
# [154]	valid_0's rmse: 0.732933
# [155]	valid_0's rmse: 0.731922
# [156]	valid_0's rmse: 0.730896
# [157]	valid_0's rmse: 0.7299
# [158]	valid_0's rmse: 0.729013
# [159]	valid_0's rmse: 0.727971
# [160]	valid_0's rmse: 0.72695
# [161]	valid_0's rmse: 0.725947
# [162]	valid_0's rmse: 0.724948
# [163]	valid_0's rmse: 0.72402
# [164]	valid_0's rmse: 0.723084
# [165]	valid_0's rmse: 0.722158
# [166]	valid_0's rmse: 0.721159
# [167]	valid_0's rmse: 0.720252
# [168]	valid_0's rmse: 0.719358
# [169]	valid_0's rmse: 0.718372
# [170]	valid_0's rmse: 0.717498
# [171]	valid_0's rmse: 0.71659
# [172]	valid_0's rmse: 0.715734
# [173]	valid_0's rmse: 0.714851
# [174]	valid_0's rmse: 0.714021
# [175]	valid_0's rmse: 0.713076
# [176]	valid_0's rmse: 0.712191
# [177]	valid_0's rmse: 0.711396
# [178]	valid_0's rmse: 0.710548
# [179]	valid_0's rmse: 0.709692
# [180]	valid_0's rmse: 0.708842
# [181]	valid_0's rmse: 0.708003
# [182]	valid_0's rmse: 0.707197
# [183]	valid_0's rmse: 0.706404
# [184]	valid_0's rmse: 0.705625
# [185]	valid_0's rmse: 0.704813
# [186]	valid_0's rmse: 0.704064
# [187]	valid_0's rmse: 0.703333
# [188]	valid_0's rmse: 0.702544
# [189]	valid_0's rmse: 0.701735
# [190]	valid_0's rmse: 0.700957
# [191]	valid_0's rmse: 0.700174
# [192]	valid_0's rmse: 0.699393
# [193]	valid_0's rmse: 0.698577
# [194]	valid_0's rmse: 0.697869
# [195]	valid_0's rmse: 0.697117
# [196]	valid_0's rmse: 0.696318
# [197]	valid_0's rmse: 0.69556
# [198]	valid_0's rmse: 0.694757
# [199]	valid_0's rmse: 0.693992
# [200]	valid_0's rmse: 0.693246
# [201]	valid_0's rmse: 0.692509
# [202]	valid_0's rmse: 0.691736
# [203]	valid_0's rmse: 0.690917
# [204]	valid_0's rmse: 0.690171
# [205]	valid_0's rmse: 0.689483
# [206]	valid_0's rmse: 0.688831
# [207]	valid_0's rmse: 0.688115
# [208]	valid_0's rmse: 0.687327
# [209]	valid_0's rmse: 0.686613
# [210]	valid_0's rmse: 0.685849
# [211]	valid_0's rmse: 0.685181
# [212]	valid_0's rmse: 0.684595
# [213]	valid_0's rmse: 0.683835
# [214]	valid_0's rmse: 0.683101
# [215]	valid_0's rmse: 0.682434
# [216]	valid_0's rmse: 0.681836
# [217]	valid_0's rmse: 0.681259
# [218]	valid_0's rmse: 0.680561
# [219]	valid_0's rmse: 0.679918
# [220]	valid_0's rmse: 0.679301
# [221]	valid_0's rmse: 0.678746
# [222]	valid_0's rmse: 0.678026
# [223]	valid_0's rmse: 0.677484
# [224]	valid_0's rmse: 0.676764
# [225]	valid_0's rmse: 0.676094
# [226]	valid_0's rmse: 0.675562
# [227]	valid_0's rmse: 0.674899
# [228]	valid_0's rmse: 0.674349
# [229]	valid_0's rmse: 0.673739
# [230]	valid_0's rmse: 0.673243
# [231]	valid_0's rmse: 0.672723
# [232]	valid_0's rmse: 0.672121
# [233]	valid_0's rmse: 0.671478
# [234]	valid_0's rmse: 0.670942
# [235]	valid_0's rmse: 0.670326
# [236]	valid_0's rmse: 0.669846
# [237]	valid_0's rmse: 0.669308
# [238]	valid_0's rmse: 0.668721
# [239]	valid_0's rmse: 0.668244
# [240]	valid_0's rmse: 0.667641
# [241]	valid_0's rmse: 0.667199
# [242]	valid_0's rmse: 0.666721
# [243]	valid_0's rmse: 0.666097
# [244]	valid_0's rmse: 0.665634
# [245]	valid_0's rmse: 0.665124
# [246]	valid_0's rmse: 0.664624
# [247]	valid_0's rmse: 0.664023
# [248]	valid_0's rmse: 0.663563
# [249]	valid_0's rmse: 0.663055
# [250]	valid_0's rmse: 0.662641
# [251]	valid_0's rmse: 0.662035
# [252]	valid_0's rmse: 0.661578
# [253]	valid_0's rmse: 0.66101
# [254]	valid_0's rmse: 0.660528
# [255]	valid_0's rmse: 0.660102
# [256]	valid_0's rmse: 0.659552
# [257]	valid_0's rmse: 0.659166
# [258]	valid_0's rmse: 0.658602
# [259]	valid_0's rmse: 0.658222
# [260]	valid_0's rmse: 0.657841
# [261]	valid_0's rmse: 0.657338
# [262]	valid_0's rmse: 0.656805
# [263]	valid_0's rmse: 0.656455
# [264]	valid_0's rmse: 0.655943
# [265]	valid_0's rmse: 0.655555
# [266]	valid_0's rmse: 0.655032
# [267]	valid_0's rmse: 0.654602
# [268]	valid_0's rmse: 0.654226
# [269]	valid_0's rmse: 0.653891
# [270]	valid_0's rmse: 0.653376
# [271]	valid_0's rmse: 0.652932
# [272]	valid_0's rmse: 0.652438
# [273]	valid_0's rmse: 0.65198
# [274]	valid_0's rmse: 0.651597
# [275]	valid_0's rmse: 0.651197
# [276]	valid_0's rmse: 0.650705
# [277]	valid_0's rmse: 0.650262
# [278]	valid_0's rmse: 0.649871
# [279]	valid_0's rmse: 0.649412
# [280]	valid_0's rmse: 0.649023
# [281]	valid_0's rmse: 0.648532
# [282]	valid_0's rmse: 0.648136
# [283]	valid_0's rmse: 0.647768
# [284]	valid_0's rmse: 0.647367
# [285]	valid_0's rmse: 0.646905
# [286]	valid_0's rmse: 0.646489
# [287]	valid_0's rmse: 0.646051
# [288]	valid_0's rmse: 0.645604
# [289]	valid_0's rmse: 0.645193
# [290]	valid_0's rmse: 0.644837
# [291]	valid_0's rmse: 0.644418
# [292]	valid_0's rmse: 0.644029
# [293]	valid_0's rmse: 0.64357
# [294]	valid_0's rmse: 0.643112
# [295]	valid_0's rmse: 0.642748
# [296]	valid_0's rmse: 0.642362
# [297]	valid_0's rmse: 0.641995
# [298]	valid_0's rmse: 0.641578
# [299]	valid_0's rmse: 0.641129
# [300]	valid_0's rmse: 0.640741
# [301]	valid_0's rmse: 0.640402
# [302]	valid_0's rmse: 0.640082
# [303]	valid_0's rmse: 0.639649
# [304]	valid_0's rmse: 0.639312
# [305]	valid_0's rmse: 0.638967
# [306]	valid_0's rmse: 0.638566
# [307]	valid_0's rmse: 0.63828
# [308]	valid_0's rmse: 0.637964
# [309]	valid_0's rmse: 0.637649
# [310]	valid_0's rmse: 0.637276
# [311]	valid_0's rmse: 0.636906
# [312]	valid_0's rmse: 0.636632
# [313]	valid_0's rmse: 0.636323
# [314]	valid_0's rmse: 0.636005
# [315]	valid_0's rmse: 0.635737
# [316]	valid_0's rmse: 0.635463
# [317]	valid_0's rmse: 0.635196
# [318]	valid_0's rmse: 0.634866
# [319]	valid_0's rmse: 0.634524
# [320]	valid_0's rmse: 0.634235
# [321]	valid_0's rmse: 0.633994
# [322]	valid_0's rmse: 0.633698
# [323]	valid_0's rmse: 0.633416
# [324]	valid_0's rmse: 0.633103
# [325]	valid_0's rmse: 0.632844
# [326]	valid_0's rmse: 0.632575
# [327]	valid_0's rmse: 0.632282
# [328]	valid_0's rmse: 0.632081
# [329]	valid_0's rmse: 0.631777
# [330]	valid_0's rmse: 0.631538
# [331]	valid_0's rmse: 0.63131
# [332]	valid_0's rmse: 0.631123
# [333]	valid_0's rmse: 0.630855
# [334]	valid_0's rmse: 0.630587
# [335]	valid_0's rmse: 0.630352
# [336]	valid_0's rmse: 0.630103
# [337]	valid_0's rmse: 0.629865
# [338]	valid_0's rmse: 0.629628
# [339]	valid_0's rmse: 0.629396
# [340]	valid_0's rmse: 0.629189
# [341]	valid_0's rmse: 0.628916
# [342]	valid_0's rmse: 0.628675
# [343]	valid_0's rmse: 0.628482
# [344]	valid_0's rmse: 0.628222
# [345]	valid_0's rmse: 0.627931
# [346]	valid_0's rmse: 0.627718
# [347]	valid_0's rmse: 0.627495
# [348]	valid_0's rmse: 0.627268
# [349]	valid_0's rmse: 0.627088
# [350]	valid_0's rmse: 0.626801
# [351]	valid_0's rmse: 0.626554
# [352]	valid_0's rmse: 0.62636
# [353]	valid_0's rmse: 0.626064
# [354]	valid_0's rmse: 0.625848
# [355]	valid_0's rmse: 0.625672
# [356]	valid_0's rmse: 0.625536
# [357]	valid_0's rmse: 0.625317
# [358]	valid_0's rmse: 0.625122
# [359]	valid_0's rmse: 0.624897
# [360]	valid_0's rmse: 0.624753
# [361]	valid_0's rmse: 0.62456
# [362]	valid_0's rmse: 0.624397
# [363]	valid_0's rmse: 0.624286
# [364]	valid_0's rmse: 0.624126
# [365]	valid_0's rmse: 0.623919
# [366]	valid_0's rmse: 0.623684
# [367]	valid_0's rmse: 0.623461
# [368]	valid_0's rmse: 0.623254
# [369]	valid_0's rmse: 0.623035
# [370]	valid_0's rmse: 0.622832
# [371]	valid_0's rmse: 0.622629
# [372]	valid_0's rmse: 0.622404
# [373]	valid_0's rmse: 0.622219
# [374]	valid_0's rmse: 0.62201
# [375]	valid_0's rmse: 0.621816
# [376]	valid_0's rmse: 0.621613
# [377]	valid_0's rmse: 0.621403
# [378]	valid_0's rmse: 0.621183
# [379]	valid_0's rmse: 0.620998
# [380]	valid_0's rmse: 0.620795
# [381]	valid_0's rmse: 0.620656
# [382]	valid_0's rmse: 0.620477
# [383]	valid_0's rmse: 0.620233
# [384]	valid_0's rmse: 0.620045
# [385]	valid_0's rmse: 0.619882
# [386]	valid_0's rmse: 0.619635
# [387]	valid_0's rmse: 0.619453
# [388]	valid_0's rmse: 0.619268
# [389]	valid_0's rmse: 0.619058
# [390]	valid_0's rmse: 0.618912
# [391]	valid_0's rmse: 0.618696
# [392]	valid_0's rmse: 0.618536
# [393]	valid_0's rmse: 0.618389
# [394]	valid_0's rmse: 0.618224
# [395]	valid_0's rmse: 0.617991
# [396]	valid_0's rmse: 0.617886
# [397]	valid_0's rmse: 0.617643
# [398]	valid_0's rmse: 0.617553
# [399]	valid_0's rmse: 0.617379
# [400]	valid_0's rmse: 0.617243
# [401]	valid_0's rmse: 0.617054
# [402]	valid_0's rmse: 0.616987
# [403]	valid_0's rmse: 0.616808
# [404]	valid_0's rmse: 0.61662
# [405]	valid_0's rmse: 0.616498
# [406]	valid_0's rmse: 0.616265
# [407]	valid_0's rmse: 0.616107
# [408]	valid_0's rmse: 0.616006
# [409]	valid_0's rmse: 0.615827
# [410]	valid_0's rmse: 0.615698
# [411]	valid_0's rmse: 0.6156
# [412]	valid_0's rmse: 0.615428
# [413]	valid_0's rmse: 0.61527
# [414]	valid_0's rmse: 0.615119
# [415]	valid_0's rmse: 0.614966
# [416]	valid_0's rmse: 0.61484
# [417]	valid_0's rmse: 0.614753
# [418]	valid_0's rmse: 0.614615
# [419]	valid_0's rmse: 0.61447
# [420]	valid_0's rmse: 0.614297
# [421]	valid_0's rmse: 0.614136
# [422]	valid_0's rmse: 0.614017
# [423]	valid_0's rmse: 0.613888
# [424]	valid_0's rmse: 0.613774
# [425]	valid_0's rmse: 0.613636
# [426]	valid_0's rmse: 0.613498
# [427]	valid_0's rmse: 0.613359
# [428]	valid_0's rmse: 0.613261
# [429]	valid_0's rmse: 0.613163
# [430]	valid_0's rmse: 0.613021
# [431]	valid_0's rmse: 0.612963
# [432]	valid_0's rmse: 0.612839
# [433]	valid_0's rmse: 0.612711
# [434]	valid_0's rmse: 0.612609
# [435]	valid_0's rmse: 0.612452
# [436]	valid_0's rmse: 0.612334
# [437]	valid_0's rmse: 0.612203
# [438]	valid_0's rmse: 0.612095
# [439]	valid_0's rmse: 0.612002
# [440]	valid_0's rmse: 0.61184
# [441]	valid_0's rmse: 0.611745
# [442]	valid_0's rmse: 0.61159
# [443]	valid_0's rmse: 0.611508
# [444]	valid_0's rmse: 0.611397
# [445]	valid_0's rmse: 0.611248
# [446]	valid_0's rmse: 0.611191
# [447]	valid_0's rmse: 0.611103
# [448]	valid_0's rmse: 0.610987
# [449]	valid_0's rmse: 0.610862
# [450]	valid_0's rmse: 0.610762
# [451]	valid_0's rmse: 0.610728
# [452]	valid_0's rmse: 0.610655
# [453]	valid_0's rmse: 0.610506
# [454]	valid_0's rmse: 0.610386
# [455]	valid_0's rmse: 0.610325
# [456]	valid_0's rmse: 0.610193
# [457]	valid_0's rmse: 0.610066
# [458]	valid_0's rmse: 0.609916
# [459]	valid_0's rmse: 0.609828
# [460]	valid_0's rmse: 0.60979
# [461]	valid_0's rmse: 0.609765
# [462]	valid_0's rmse: 0.609658
# [463]	valid_0's rmse: 0.609515
# [464]	valid_0's rmse: 0.609454
# [465]	valid_0's rmse: 0.609395
# [466]	valid_0's rmse: 0.609309
# [467]	valid_0's rmse: 0.609187
# [468]	valid_0's rmse: 0.609059
# [469]	valid_0's rmse: 0.608983
# [470]	valid_0's rmse: 0.608871
# [471]	valid_0's rmse: 0.608769
# [472]	valid_0's rmse: 0.608714
# [473]	valid_0's rmse: 0.608604
# [474]	valid_0's rmse: 0.608523
# [475]	valid_0's rmse: 0.608457
# [476]	valid_0's rmse: 0.608382
# [477]	valid_0's rmse: 0.608265
# [478]	valid_0's rmse: 0.608188
# [479]	valid_0's rmse: 0.608116
# [480]	valid_0's rmse: 0.608084
# [481]	valid_0's rmse: 0.608021
# [482]	valid_0's rmse: 0.607917
# [483]	valid_0's rmse: 0.6078
# [484]	valid_0's rmse: 0.607643
# [485]	valid_0's rmse: 0.607583
# [486]	valid_0's rmse: 0.607438
# [487]	valid_0's rmse: 0.607369
# [488]	valid_0's rmse: 0.607346
# [489]	valid_0's rmse: 0.607344
# [490]	valid_0's rmse: 0.607215
# [491]	valid_0's rmse: 0.60716
# [492]	valid_0's rmse: 0.607038
# [493]	valid_0's rmse: 0.606974
# [494]	valid_0's rmse: 0.606878
# [495]	valid_0's rmse: 0.606809
# [496]	valid_0's rmse: 0.6067
# [497]	valid_0's rmse: 0.606621
# [498]	valid_0's rmse: 0.606529
# [499]	valid_0's rmse: 0.606508
# ...
# [449]	valid_0's rmse: 0.675823
# [450]	valid_0's rmse: 0.67578
# [451]	valid_0's rmse: 0.675733
# [452]	valid_0's rmse: 0.675731
# [453]	valid_0's rmse: 0.675663
# [454]	valid_0's rmse: 0.675611
# [455]	valid_0's rmse: 0.675571
# [456]	valid_0's rmse: 0.675488
# [457]	valid_0's rmse: 0.675442
# [458]	valid_0's rmse: 0.675426
# [459]	valid_0's rmse: 0.675371
# [460]	valid_0's rmse: 0.675298
# [461]	valid_0's rmse: 0.675261
# [462]	valid_0's rmse: 0.675211
# [463]	valid_0's rmse: 0.675153
# [464]	valid_0's rmse: 0.675103
# [465]	valid_0's rmse: 0.675087
# [466]	valid_0's rmse: 0.675028
# [467]	valid_0's rmse: 0.67503
# [468]	valid_0's rmse: 0.674967
# [469]	valid_0's rmse: 0.674984
# [470]	valid_0's rmse: 0.674915
# [471]	valid_0's rmse: 0.674905
# [472]	valid_0's rmse: 0.674852
# [473]	valid_0's rmse: 0.674852
# [474]	valid_0's rmse: 0.674754
# [475]	valid_0's rmse: 0.674787
# [476]	valid_0's rmse: 0.674799
# [477]	valid_0's rmse: 0.674766
# [478]	valid_0's rmse: 0.674743
# [479]	valid_0's rmse: 0.674708
# [480]	valid_0's rmse: 0.67466
# [481]	valid_0's rmse: 0.674584
# [482]	valid_0's rmse: 0.674518
# [483]	valid_0's rmse: 0.674539
# [484]	valid_0's rmse: 0.674476
# [485]	valid_0's rmse: 0.67442
# [486]	valid_0's rmse: 0.674353
# [487]	valid_0's rmse: 0.674296
# [488]	valid_0's rmse: 0.674253
# [489]	valid_0's rmse: 0.674215
# [490]	valid_0's rmse: 0.674182
# [491]	valid_0's rmse: 0.674145
# [492]	valid_0's rmse: 0.67413
# [493]	valid_0's rmse: 0.674097
# [494]	valid_0's rmse: 0.674036
# [495]	valid_0's rmse: 0.673967
# [496]	valid_0's rmse: 0.67393
# [497]	valid_0's rmse: 0.673829
# [498]	valid_0's rmse: 0.673844
# [499]	valid_0's rmse: 0.673888
# [500]	valid_0's rmse: 0.673832
# [501]	valid_0's rmse: 0.673761
# [502]	valid_0's rmse: 0.673752
# [503]	valid_0's rmse: 0.673716
# [504]	valid_0's rmse: 0.673669
# [505]	valid_0's rmse: 0.67359
# [506]	valid_0's rmse: 0.673616
# [507]	valid_0's rmse: 0.673596
# [508]	valid_0's rmse: 0.673606
# [509]	valid_0's rmse: 0.673555
# [510]	valid_0's rmse: 0.673481
# [511]	valid_0's rmse: 0.673423
# [512]	valid_0's rmse: 0.673334
# [513]	valid_0's rmse: 0.673305
# [514]	valid_0's rmse: 0.673336
# [515]	valid_0's rmse: 0.673296
# [516]	valid_0's rmse: 0.673254
# [517]	valid_0's rmse: 0.673305
# [518]	valid_0's rmse: 0.673218
# [519]	valid_0's rmse: 0.673167
# [520]	valid_0's rmse: 0.673142
# [521]	valid_0's rmse: 0.673063
# [522]	valid_0's rmse: 0.672989
# [523]	valid_0's rmse: 0.672908
# [524]	valid_0's rmse: 0.672781
# [525]	valid_0's rmse: 0.67271
# [526]	valid_0's rmse: 0.672637
# [527]	valid_0's rmse: 0.672611
# [528]	valid_0's rmse: 0.672644
# [529]	valid_0's rmse: 0.67257
# [530]	valid_0's rmse: 0.672498
# [531]	valid_0's rmse: 0.672501
# [532]	valid_0's rmse: 0.672425
# [533]	valid_0's rmse: 0.672384
# [534]	valid_0's rmse: 0.672353
# [535]	valid_0's rmse: 0.672336
# [536]	valid_0's rmse: 0.672322
# [537]	valid_0's rmse: 0.672299
# [538]	valid_0's rmse: 0.672208
# [539]	valid_0's rmse: 0.67213
# [540]	valid_0's rmse: 0.672065
# [541]	valid_0's rmse: 0.672049
# [542]	valid_0's rmse: 0.672055
# [543]	valid_0's rmse: 0.671979
# [544]	valid_0's rmse: 0.671941
# [545]	valid_0's rmse: 0.671925
# [546]	valid_0's rmse: 0.671942
# [547]	valid_0's rmse: 0.671887
# [548]	valid_0's rmse: 0.671833
# [549]	valid_0's rmse: 0.671788
# [550]	valid_0's rmse: 0.671767
# [551]	valid_0's rmse: 0.671728
# [552]	valid_0's rmse: 0.671766
# [553]	valid_0's rmse: 0.671729
# [554]	valid_0's rmse: 0.67174
# [555]	valid_0's rmse: 0.671704
# [556]	valid_0's rmse: 0.671664
# [557]	valid_0's rmse: 0.67171
# [558]	valid_0's rmse: 0.671689
# [559]	valid_0's rmse: 0.671686
# [560]	valid_0's rmse: 0.67166
# [561]	valid_0's rmse: 0.671587
# [562]	valid_0's rmse: 0.671579
# [563]	valid_0's rmse: 0.671577
# [564]	valid_0's rmse: 0.671516
# [565]	valid_0's rmse: 0.671454
# [566]	valid_0's rmse: 0.671514
# [567]	valid_0's rmse: 0.671469
# [568]	valid_0's rmse: 0.671415
# [569]	valid_0's rmse: 0.671345
# [570]	valid_0's rmse: 0.671295
# [571]	valid_0's rmse: 0.671356
# [572]	valid_0's rmse: 0.671322
# [573]	valid_0's rmse: 0.671406
# [574]	valid_0's rmse: 0.671319
# [575]	valid_0's rmse: 0.671247
# [576]	valid_0's rmse: 0.671216
# [577]	valid_0's rmse: 0.671164
# [578]	valid_0's rmse: 0.671106
# [579]	valid_0's rmse: 0.671053
# [580]	valid_0's rmse: 0.671041
# [581]	valid_0's rmse: 0.671031
# [582]	valid_0's rmse: 0.670981
# [583]	valid_0's rmse: 0.670972
# [584]	valid_0's rmse: 0.670967
# [585]	valid_0's rmse: 0.670959
# [586]	valid_0's rmse: 0.670913
# [587]	valid_0's rmse: 0.670892
# [588]	valid_0's rmse: 0.670846
# [589]	valid_0's rmse: 0.670848
# [590]	valid_0's rmse: 0.670852
# [591]	valid_0's rmse: 0.67081
# [592]	valid_0's rmse: 0.670819
# [593]	valid_0's rmse: 0.670786
# [594]	valid_0's rmse: 0.670775
# [595]	valid_0's rmse: 0.670784
# [596]	valid_0's rmse: 0.67075
# [597]	valid_0's rmse: 0.670761
# [598]	valid_0's rmse: 0.67077
# [599]	valid_0's rmse: 0.670717
# [600]	valid_0's rmse: 0.670707
# [601]	valid_0's rmse: 0.670676
# [602]	valid_0's rmse: 0.670695
# [603]	valid_0's rmse: 0.67066
# [604]	valid_0's rmse: 0.67065
# [605]	valid_0's rmse: 0.670621
# [606]	valid_0's rmse: 0.670584
# [607]	valid_0's rmse: 0.670594
# [608]	valid_0's rmse: 0.670606
# [609]	valid_0's rmse: 0.670571
# [610]	valid_0's rmse: 0.670511
# [611]	valid_0's rmse: 0.670469
# [612]	valid_0's rmse: 0.670395
# [613]	valid_0's rmse: 0.670414
# [614]	valid_0's rmse: 0.670437
# [615]	valid_0's rmse: 0.670365
# [616]	valid_0's rmse: 0.670384
# [617]	valid_0's rmse: 0.670324
# [618]	valid_0's rmse: 0.67024
# [619]	valid_0's rmse: 0.670201
# [620]	valid_0's rmse: 0.670176
# [621]	valid_0's rmse: 0.670166
# [622]	valid_0's rmse: 0.670173
# [623]	valid_0's rmse: 0.670124
# [624]	valid_0's rmse: 0.670056
# [625]	valid_0's rmse: 0.670051
# [626]	valid_0's rmse: 0.670019
# [627]	valid_0's rmse: 0.670002
# [628]	valid_0's rmse: 0.669953
# [629]	valid_0's rmse: 0.669991
# [630]	valid_0's rmse: 0.66997
# [631]	valid_0's rmse: 0.66994
# [632]	valid_0's rmse: 0.669925
# [633]	valid_0's rmse: 0.669913
# [634]	valid_0's rmse: 0.669958
# [635]	valid_0's rmse: 0.669995
# [636]	valid_0's rmse: 0.669981
# [637]	valid_0's rmse: 0.66997
# [638]	valid_0's rmse: 0.669986
# [639]	valid_0's rmse: 0.669971
# [640]	valid_0's rmse: 0.669992
# [641]	valid_0's rmse: 0.669989
# [642]	valid_0's rmse: 0.669939
# [643]	valid_0's rmse: 0.669961
# [644]	valid_0's rmse: 0.669936
# [645]	valid_0's rmse: 0.669964
# [646]	valid_0's rmse: 0.669976
# [647]	valid_0's rmse: 0.669956
# [648]	valid_0's rmse: 0.669966
# [649]	valid_0's rmse: 0.669941
# [650]	valid_0's rmse: 0.669965
# [651]	valid_0's rmse: 0.670004
# [652]	valid_0's rmse: 0.67003
# [653]	valid_0's rmse: 0.670008
# [654]	valid_0's rmse: 0.670042
# [655]	valid_0's rmse: 0.670022
# [656]	valid_0's rmse: 0.670061
# [657]	valid_0's rmse: 0.670041
# [658]	valid_0's rmse: 0.670026
# [659]	valid_0's rmse: 0.670006
# [660]	valid_0's rmse: 0.670016
# [661]	valid_0's rmse: 0.669997
# [662]	valid_0's rmse: 0.66999
# [663]	valid_0's rmse: 0.669988
# [664]	valid_0's rmse: 0.669957
# [665]	valid_0's rmse: 0.66992
# [666]	valid_0's rmse: 0.669903
# [667]	valid_0's rmse: 0.669857
# [668]	valid_0's rmse: 0.669828
# [669]	valid_0's rmse: 0.669783
# [670]	valid_0's rmse: 0.669826
# [671]	valid_0's rmse: 0.6698
# [672]	valid_0's rmse: 0.669782
# [673]	valid_0's rmse: 0.669765
# [674]	valid_0's rmse: 0.669751
# [675]	valid_0's rmse: 0.66974
# [676]	valid_0's rmse: 0.669701
# [677]	valid_0's rmse: 0.669627
# [678]	valid_0's rmse: 0.6696
# [679]	valid_0's rmse: 0.669593
# [680]	valid_0's rmse: 0.669612
# [681]	valid_0's rmse: 0.669542
# [682]	valid_0's rmse: 0.669511
# [683]	valid_0's rmse: 0.669527
# [684]	valid_0's rmse: 0.669495
# [685]	valid_0's rmse: 0.669516
# [686]	valid_0's rmse: 0.669538
# [687]	valid_0's rmse: 0.669479
# [688]	valid_0's rmse: 0.669497
# [689]	valid_0's rmse: 0.669462
# [690]	valid_0's rmse: 0.669434
# [691]	valid_0's rmse: 0.66938
# [692]	valid_0's rmse: 0.669346
# [693]	valid_0's rmse: 0.669322
# [694]	valid_0's rmse: 0.669344
# [695]	valid_0's rmse: 0.669343
# [696]	valid_0's rmse: 0.669306
# [697]	valid_0's rmse: 0.669306
# [698]	valid_0's rmse: 0.669324
# [699]	valid_0's rmse: 0.669324
# [700]	valid_0's rmse: 0.669316
# [701]	valid_0's rmse: 0.66934
# [702]	valid_0's rmse: 0.669351
# [703]	valid_0's rmse: 0.669339
# [704]	valid_0's rmse: 0.669353
# [705]	valid_0's rmse: 0.669336
# [706]	valid_0's rmse: 0.669329
# [707]	valid_0's rmse: 0.669356
# [708]	valid_0's rmse: 0.669363
# [709]	valid_0's rmse: 0.669378
# [710]	valid_0's rmse: 0.669371
# [711]	valid_0's rmse: 0.669342
# [712]	valid_0's rmse: 0.669293
# [713]	valid_0's rmse: 0.669248
# [714]	valid_0's rmse: 0.669225
# [715]	valid_0's rmse: 0.669257
# [716]	valid_0's rmse: 0.669215
# [717]	valid_0's rmse: 0.669183
# [718]	valid_0's rmse: 0.669135
# [719]	valid_0's rmse: 0.669095
# [720]	valid_0's rmse: 0.669047
# [721]	valid_0's rmse: 0.669052
# [722]	valid_0's rmse: 0.669081
# [723]	valid_0's rmse: 0.669046
# [724]	valid_0's rmse: 0.669047
# [725]	valid_0's rmse: 0.669
# [726]	valid_0's rmse: 0.669017
# [727]	valid_0's rmse: 0.668971
# [728]	valid_0's rmse: 0.668989
# [729]	valid_0's rmse: 0.66895
# [730]	valid_0's rmse: 0.668938
# [731]	valid_0's rmse: 0.668931
# [732]	valid_0's rmse: 0.668857
# [733]	valid_0's rmse: 0.668775
# [734]	valid_0's rmse: 0.66877
# [735]	valid_0's rmse: 0.668759
# [736]	valid_0's rmse: 0.66869
# [737]	valid_0's rmse: 0.668741
# [738]	valid_0's rmse: 0.668729
# [739]	valid_0's rmse: 0.668682
# [740]	valid_0's rmse: 0.668659
# [741]	valid_0's rmse: 0.668576
# [742]	valid_0's rmse: 0.668548
# [743]	valid_0's rmse: 0.668576
# [744]	valid_0's rmse: 0.668634
# [745]	valid_0's rmse: 0.66863
# [746]	valid_0's rmse: 0.668617
# [747]	valid_0's rmse: 0.668654
# [748]	valid_0's rmse: 0.668619
# [749]	valid_0's rmse: 0.668616
# [750]	valid_0's rmse: 0.66859
# [751]	valid_0's rmse: 0.668589
# [752]	valid_0's rmse: 0.668643
# [753]	valid_0's rmse: 0.668643
# [754]	valid_0's rmse: 0.668575
# [755]	valid_0's rmse: 0.668545
# [756]	valid_0's rmse: 0.668615
# [757]	valid_0's rmse: 0.668537
# [758]	valid_0's rmse: 0.668534
# [759]	valid_0's rmse: 0.668601
# [760]	valid_0's rmse: 0.668531
# [761]	valid_0's rmse: 0.668603
# [762]	valid_0's rmse: 0.668595
# [763]	valid_0's rmse: 0.668576
# [764]	valid_0's rmse: 0.668562
# [765]	valid_0's rmse: 0.668485
# [766]	valid_0's rmse: 0.668414
# [767]	valid_0's rmse: 0.668488
# [768]	valid_0's rmse: 0.668422
# [769]	valid_0's rmse: 0.668497
# [770]	valid_0's rmse: 0.668427
# [771]	valid_0's rmse: 0.6685
# [772]	valid_0's rmse: 0.668426
# [773]	valid_0's rmse: 0.668371
# [774]	valid_0's rmse: 0.66845
# [775]	valid_0's rmse: 0.668447
# [776]	valid_0's rmse: 0.668401
# [777]	valid_0's rmse: 0.668321
# [778]	valid_0's rmse: 0.668304
# [779]	valid_0's rmse: 0.668238
# [780]	valid_0's rmse: 0.668218
# [781]	valid_0's rmse: 0.668222
# [782]	valid_0's rmse: 0.668297
# [783]	valid_0's rmse: 0.668235
# [784]	valid_0's rmse: 0.668305
# [785]	valid_0's rmse: 0.668323
# [786]	valid_0's rmse: 0.668268
# [787]	valid_0's rmse: 0.668268
# [788]	valid_0's rmse: 0.668343
# [789]	valid_0's rmse: 0.668343
# [790]	valid_0's rmse: 0.668291
# [791]	valid_0's rmse: 0.668319
# [792]	valid_0's rmse: 0.668318
# [793]	valid_0's rmse: 0.66828
# [794]	valid_0's rmse: 0.668255
# [795]	valid_0's rmse: 0.668267
# [796]	valid_0's rmse: 0.668256
# [797]	valid_0's rmse: 0.668215
# [798]	valid_0's rmse: 0.668262
# [799]	valid_0's rmse: 0.668222
# [800]	valid_0's rmse: 0.668292
# [801]	valid_0's rmse: 0.668261
# [802]	valid_0's rmse: 0.668244
# [803]	valid_0's rmse: 0.668235
# [804]	valid_0's rmse: 0.668312
# [805]	valid_0's rmse: 0.668285
# [806]	valid_0's rmse: 0.668253
# [807]	valid_0's rmse: 0.668266
# [808]	valid_0's rmse: 0.668323
# [809]	valid_0's rmse: 0.668276
# [810]	valid_0's rmse: 0.668256
# [811]	valid_0's rmse: 0.668273
# [812]	valid_0's rmse: 0.66824
# [813]	valid_0's rmse: 0.668221
# [814]	valid_0's rmse: 0.668197
# [815]	valid_0's rmse: 0.668185
# [816]	valid_0's rmse: 0.668168
# [817]	valid_0's rmse: 0.668146
# [818]	valid_0's rmse: 0.668134
# [819]	valid_0's rmse: 0.668101
# [820]	valid_0's rmse: 0.668091
# [821]	valid_0's rmse: 0.668098
# [822]	valid_0's rmse: 0.668104
# [823]	valid_0's rmse: 0.668079
# [824]	valid_0's rmse: 0.668061
# [825]	valid_0's rmse: 0.668068
# [826]	valid_0's rmse: 0.668047
# [827]	valid_0's rmse: 0.668044
# [828]	valid_0's rmse: 0.668024
# [829]	valid_0's rmse: 0.668028
# [830]	valid_0's rmse: 0.668017
# [831]	valid_0's rmse: 0.668025
# [832]	valid_0's rmse: 0.668014
# [833]	valid_0's rmse: 0.667999
# [834]	valid_0's rmse: 0.667988
# [835]	valid_0's rmse: 0.667966
# [836]	valid_0's rmse: 0.667947
# [837]	valid_0's rmse: 0.667969
# [838]	valid_0's rmse: 0.667982
# [839]	valid_0's rmse: 0.667979
# [840]	valid_0's rmse: 0.667992
# [841]	valid_0's rmse: 0.66801
# [842]	valid_0's rmse: 0.66797
# [843]	valid_0's rmse: 0.667933
# [844]	valid_0's rmse: 0.667945
# [845]	valid_0's rmse: 0.66792
# [846]	valid_0's rmse: 0.667948
# [847]	valid_0's rmse: 0.667946
# [848]	valid_0's rmse: 0.667965
# [849]	valid_0's rmse: 0.667957
# [850]	valid_0's rmse: 0.667969
# [851]	valid_0's rmse: 0.667926
# [852]	valid_0's rmse: 0.667925
# [853]	valid_0's rmse: 0.667934
# [854]	valid_0's rmse: 0.667936
# [855]	valid_0's rmse: 0.667894
# [856]	valid_0's rmse: 0.667905
# [857]	valid_0's rmse: 0.667887
# [858]	valid_0's rmse: 0.667887
# [859]	valid_0's rmse: 0.667873
# [860]	valid_0's rmse: 0.667873
# [861]	valid_0's rmse: 0.667843
# [862]	valid_0's rmse: 0.667843
# [863]	valid_0's rmse: 0.667853
# [864]	valid_0's rmse: 0.667841
# [865]	valid_0's rmse: 0.667845
# [866]	valid_0's rmse: 0.667869
# [867]	valid_0's rmse: 0.667869
# [868]	valid_0's rmse: 0.667869
# [869]	valid_0's rmse: 0.667859
# [870]	valid_0's rmse: 0.667873
# [871]	valid_0's rmse: 0.667871
# [872]	valid_0's rmse: 0.667882
# [873]	valid_0's rmse: 0.667883
# [874]	valid_0's rmse: 0.667903
# [875]	valid_0's rmse: 0.66786
# [876]	valid_0's rmse: 0.66786
# [877]	valid_0's rmse: 0.667866
# [878]	valid_0's rmse: 0.667856
# [879]	valid_0's rmse: 0.667866
# [880]	valid_0's rmse: 0.667912
# [881]	valid_0's rmse: 0.667925
# [882]	valid_0's rmse: 0.667903
# [883]	valid_0's rmse: 0.667897
# [884]	valid_0's rmse: 0.667893
# [885]	valid_0's rmse: 0.667892
# [886]	valid_0's rmse: 0.667895
# [887]	valid_0's rmse: 0.667911
# [888]	valid_0's rmse: 0.667907
# [889]	valid_0's rmse: 0.667902
# [890]	valid_0's rmse: 0.667926
# [891]	valid_0's rmse: 0.667931
# [892]	valid_0's rmse: 0.667942
# [893]	valid_0's rmse: 0.667945
# [894]	valid_0's rmse: 0.667958
# [895]	valid_0's rmse: 0.667955
# [896]	valid_0's rmse: 0.667999
# [897]	valid_0's rmse: 0.668009
# [898]	valid_0's rmse: 0.668015
# [899]	valid_0's rmse: 0.668002
# [900]	valid_0's rmse: 0.668019
# [901]	valid_0's rmse: 0.668007
# [902]	valid_0's rmse: 0.668041
# [903]	valid_0's rmse: 0.668046
# [904]	valid_0's rmse: 0.668057
# [905]	valid_0's rmse: 0.668099
# [906]	valid_0's rmse: 0.668122
# [907]	valid_0's rmse: 0.668163
# [908]	valid_0's rmse: 0.66816
# [909]	valid_0's rmse: 0.66818
# [910]	valid_0's rmse: 0.668204
# [911]	valid_0's rmse: 0.668216
# [912]	valid_0's rmse: 0.668208
# [913]	valid_0's rmse: 0.668218
# [914]	valid_0's rmse: 0.668247
# [915]	valid_0's rmse: 0.66827
# [916]	valid_0's rmse: 0.66826
# [917]	valid_0's rmse: 0.668252
# [918]	valid_0's rmse: 0.66822
# [919]	valid_0's rmse: 0.668237
# [920]	valid_0's rmse: 0.66825
# [921]	valid_0's rmse: 0.668218
# [922]	valid_0's rmse: 0.668209
# [923]	valid_0's rmse: 0.668177
# [924]	valid_0's rmse: 0.66822
# [925]	valid_0's rmse: 0.66821
# [926]	valid_0's rmse: 0.668182
# [927]	valid_0's rmse: 0.668178
# [928]	valid_0's rmse: 0.668174
# [929]	valid_0's rmse: 0.668179
# [930]	valid_0's rmse: 0.668191
# [931]	valid_0's rmse: 0.668202
# [932]	valid_0's rmse: 0.668233
# [933]	valid_0's rmse: 0.668208
# [934]	valid_0's rmse: 0.66822
# [935]	valid_0's rmse: 0.668236
# [936]	valid_0's rmse: 0.668283
# [937]	valid_0's rmse: 0.668247
# [938]	valid_0's rmse: 0.668265
# [939]	valid_0's rmse: 0.668255
# [940]	valid_0's rmse: 0.668247
# [941]	valid_0's rmse: 0.668249
# [942]	valid_0's rmse: 0.66824
# [943]	valid_0's rmse: 0.668185
# [944]	valid_0's rmse: 0.668224
# [945]	valid_0's rmse: 0.668204
# [946]	valid_0's rmse: 0.66823
# [947]	valid_0's rmse: 0.66825
# [948]	valid_0's rmse: 0.668245
# [949]	valid_0's rmse: 0.668238
# [950]	valid_0's rmse: 0.668229
# [951]	valid_0's rmse: 0.6682
# [952]	valid_0's rmse: 0.668202
# [953]	valid_0's rmse: 0.668197
# [954]	valid_0's rmse: 0.668188
# [955]	valid_0's rmse: 0.668213
# [956]	valid_0's rmse: 0.668237
# [957]	valid_0's rmse: 0.668221
# [958]	valid_0's rmse: 0.668241
# [959]	valid_0's rmse: 0.66823
# [960]	valid_0's rmse: 0.668194
# [961]	valid_0's rmse: 0.668153
# [962]	valid_0's rmse: 0.668171
# [963]	valid_0's rmse: 0.668156
# [964]	valid_0's rmse: 0.668138
# --------------------
# Eval RMSE: 0.6141159819456373

# %% [markdown]
# ## Test Inference

# %%
data_path     = '/kaggle/input/linking-writing-processes-to-writing-quality/'

print('< Testing Data >')
test_logs   = pl.scan_csv(data_path + 'test_logs.csv')
test_feats  = dev_feats(test_logs)
test_feats  = test_feats.collect().to_pandas()

test_logs             = test_logs.collect().to_pandas()
test_essays           = get_essay_df(test_logs)
test_feats            = test_feats.merge(word_feats(test_essays), on='id', how='left')
test_feats            = test_feats.merge(sent_feats(test_essays), on='id', how='left')
test_feats            = test_feats.merge(parag_feats(test_essays), on='id', how='left')
test_feats            = test_feats.merge(get_keys_pressed_per_second(test_logs), on='id', how='left')
test_feats            = test_feats.merge(product_to_keys(test_logs, test_essays), on='id', how='left')


test_ids = test_feats['id'].values
testin_x = test_feats.drop(['id'], axis=1)

print('< Learning and Evaluation >')
param = {
        'n_estimators': 1024,
         'learning_rate': 0.005,
         'metric': 'rmse',
         'random_state': 42,
         'force_col_wise': True,
         'verbosity': 1,
         'early_stopping_round': 100
        }


solution = LGBMRegressor(**param)
test_y_pred = inference(test_x=testin_x.copy())
sub = pd.DataFrame({'id': test_ids, 'score': test_y_pred})
sub.to_csv('submission.csv', index=False)
# Out:
# < Testing Data >
# < Count by values features >
# < Input words stats features >
# < Numerical columns features >
# < Categorical columns features >
# < Idle time features >
# < P-bursts features >
# < R-bursts features >
# < Learning and Evaluation >

# %%
# !rm -rf /kaggle/working/results
# !rm -rf /kaggle/working/feature_selection
